# %% [markdown]
# Data Engineering - Group 1
# Healthcare - Flu Tracker
# ---

# %% [markdown]
# ## Extraction

# %%
import pandas as pd

# Step 1: Load CSV data into Pandas DataFrames for the two CSV files
file_path_ilinet_state = "ILINet.csv"
file_path_clinical_labs_national = "WHO_NREVSS_Clinical_Labs.csv"
file_path_ilinet_national = "ILINetnational.csv"
file_path_clinical_labs_state = "WHO_NREVSS_Clinical_Labsstate.csv"

df_ilinet_state = pd.read_csv(file_path_ilinet_state)
df_clinical_labs_national = pd.read_csv(file_path_clinical_labs_national)
df_ilinet_national = pd.read_csv(file_path_ilinet_national)
df_clinical_labs_state = pd.read_csv(file_path_clinical_labs_state)

# Display the first few rows of each DataFrame
print("First few rows of ILINet State DataFrame:")
print(df_ilinet_state.head())

print("\nFirst few rows of WHO_NREVSS_Clinical_Labs National DataFrame:")
print(df_clinical_labs_national.head())

print("First few rows of ILINet National DataFrame:")
print(df_ilinet_national.head())

print("\nFirst few rows of WHO_NREVSS_Clinical_Labs State DataFrame:")
print(df_clinical_labs_state.head())
# Out:
# First few rows of ILINet State DataFrame:
#   REGION TYPE      REGION  YEAR  WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4  \
# 0      States     Alabama  2010    40              X         2.13477       X
# 1      States      Alaska  2010    40              X        0.875146       X
# 2      States     Arizona  2010    40              X        0.674721       X
# 3      States    Arkansas  2010    40              X        0.696056       X
# 4      States  California  2010    40              X         1.95412       X
#
#   AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS  \
# 0         X         X        X         X      X      249                35
# 1         X         X        X         X      X       15                 7
# 2         X         X        X         X      X      172                49
# 3         X         X        X         X      X       18                15
# 4         X         X        X         X      X      632               112
#
#   TOTAL PATIENTS
# 0          11664
# 1           1714
# 2          25492
# 3           2586
# 4          32342
#
# First few rows of WHO_NREVSS_Clinical_Labs National DataFrame:
#   REGION TYPE REGION  YEAR  WEEK  TOTAL SPECIMENS  TOTAL A  TOTAL B  \
# 0    National      X  2015    40            12029       84       43
# 1    National      X  2015    41            13111      116       54
# 2    National      X  2015    42            13441       97       52
# 3    National      X  2015    43            13537       98       52
# 4    National      X  2015    44            14687       97       68
#
#    PERCENT POSITIVE  PERCENT A  PERCENT B
# 0           1.05578   0.698312   0.357469
# 1           1.29662   0.884753   0.411868
# 2           1.10855   0.721672   0.386876
# 3           1.10807   0.723942   0.384132
# 4           1.12344   0.660448   0.462994
# First few rows of ILINet National DataFrame:
#   REGION TYPE REGION  YEAR  WEEK  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  \
# 0    National      X  1997    40         1.10148          1.21686      179
# 1    National      X  1997    41         1.20007          1.28064      199
# 2    National      X  1997    42         1.37876          1.23906      228
# 3    National      X  1997    43         1.19920          1.14473      188
# 4    National      X  1997    44         1.65618          1.26112      217
#
#   AGE 25-49 AGE 25-64  AGE 5-24 AGE 50-64  AGE 65  ILITOTAL  \
# 0         X       157       205         X      29       570
# 1         X       151       242         X      23       615
# 2         X       153       266         X      34       681
# 3         X       193       236         X      36       653
# 4         X       162       280         X      41       700
#
#    NUM. OF PROVIDERS  TOTAL PATIENTS
# 0                192           46842
# 1                191           48023
# 2                219           54961
# 3                213           57044
# 4                213           55506
#
# First few rows of WHO_NREVSS_Clinical_Labs State DataFrame:
#   REGION TYPE      REGION  YEAR  WEEK TOTAL SPECIMENS TOTAL A TOTAL B  \
# 0      States     Alabama  2015    40             167       2       3
# 1      States      Alaska  2015    40               X       X       X
# 2      States     Arizona  2015    40              55       0       0
# 3      States    Arkansas  2015    40              26       0       1
# 4      States  California  2015    40             683       2       0
#
#   PERCENT POSITIVE PERCENT A PERCENT B
# 0             2.99       1.2       1.8
# 1                X         X         X
# 2                0         0         0
# 3             3.85         0      3.85
# 4             0.29      0.29         0

# %%
df_ilinet_selected_state = df_ilinet_state[['REGION','YEAR','WEEK', 'AGE 0-4', 'AGE 25-49', 'AGE 25-64', 'AGE 5-24', 'AGE 50-64', 'AGE 65', 'ILITOTAL', 'NUM. OF PROVIDERS', 'TOTAL PATIENTS']]

df_clinical_labs_selected_national = df_clinical_labs_national[['REGION TYPE', 'TOTAL SPECIMENS', 'TOTAL A', 'TOTAL B', 'YEAR','WEEK']]

df_ilinet_selected_national = df_ilinet_national[['REGION TYPE', 'YEAR', 'WEEK','AGE 0-4', 'AGE 25-49', 'AGE 25-64', 'AGE 5-24', 'AGE 50-64', 'AGE 65', 'ILITOTAL', 'NUM. OF PROVIDERS', 'TOTAL PATIENTS']]

df_clinical_labs_selected_state = df_clinical_labs_state[['REGION', 'TOTAL SPECIMENS', 'TOTAL A', 'TOTAL B', 'YEAR','WEEK']]

# Display the selected DataFrames
print("Selected Columns from ILINet DataFrame:")
print(df_ilinet_selected_state.head())

print("\nSelected Columns from WHO_NREVVS_Clinical_Labs DataFrame:")
print(df_clinical_labs_selected_national.head())

print("Selected Columns from ILINet DataFrame:")
print(df_ilinet_selected_national.head())

print("\nSelected Columns from WHO_NREVVS_Clinical_Labs DataFrame:")
print(df_clinical_labs_selected_state.head())
# Out:
# Selected Columns from ILINet DataFrame:
#        REGION  YEAR  WEEK AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64  \
# 0     Alabama  2010    40       X         X         X        X         X
# 1      Alaska  2010    40       X         X         X        X         X
# 2     Arizona  2010    40       X         X         X        X         X
# 3    Arkansas  2010    40       X         X         X        X         X
# 4  California  2010    40       X         X         X        X         X
#
#   AGE 65 ILITOTAL NUM. OF PROVIDERS TOTAL PATIENTS
# 0      X      249                35          11664
# 1      X       15                 7           1714
# 2      X      172                49          25492
# 3      X       18                15           2586
# 4      X      632               112          32342
#
# Selected Columns from WHO_NREVVS_Clinical_Labs DataFrame:
#   REGION TYPE  TOTAL SPECIMENS  TOTAL A  TOTAL B  YEAR  WEEK
# 0    National            12029       84       43  2015    40
# 1    National            13111      116       54  2015    41
# 2    National            13441       97       52  2015    42
# 3    National            13537       98       52  2015    43
# 4    National            14687       97       68  2015    44
# Selected Columns from ILINet DataFrame:
#   REGION TYPE  YEAR  WEEK  AGE 0-4 AGE 25-49 AGE 25-64  AGE 5-24 AGE 50-64  \
# 0    National  1997    40      179         X       157       205         X
# 1    National  1997    41      199         X       151       242         X
# 2    National  1997    42      228         X       153       266         X
# 3    National  1997    43      188         X       193       236         X
# 4    National  1997    44      217         X       162       280         X
#
#    AGE 65  ILITOTAL  NUM. OF PROVIDERS  TOTAL PATIENTS
# 0      29       570                192           46842
# 1      23       615                191           48023
# 2      34       681                219           54961
# 3      36       653                213           57044
# 4      41       700                213           55506
#
# Selected Columns from WHO_NREVVS_Clinical_Labs DataFrame:
#        REGION TOTAL SPECIMENS TOTAL A TOTAL B  YEAR  WEEK
# 0     Alabama             167       2       3  2015    40
# 1      Alaska               X       X       X  2015    40
# 2     Arizona              55       0       0  2015    40
# 3    Arkansas              26       0       1  2015    40
# 4  California             683       2       0  2015    40

# %% [markdown]
# ## Transformation

# %%
def CreateClinicalDF(clinical_data_set):
    #Take the state dataframes and filter for year 2023 and filter/change column types of totals to int
    df_clinical_state = clinical_data_set[clinical_data_set['YEAR'] == 2023]
    #some states do not have data
    df_clinical_state = df_clinical_state[df_clinical_state['TOTAL A'] != 'X']
    df_clinical_state["TOTAL A"] = df_clinical_state["TOTAL A"].astype(int)
    df_clinical_state["TOTAL B"] = df_clinical_state["TOTAL B"].astype(int)
    df_clinical_state["TOTAL SPECIMENS"] = df_clinical_state["TOTAL SPECIMENS"].astype(int)
    return(df_clinical_state)

# %%
def CreateILIDF(ili_data_set):
    #Take the state dataframes and filter for year 2023 and filter/change column types of totals to int
    df_ili = ili_data_set[ili_data_set['YEAR'] == 2023]
    #some states do not have data
    df_ili = df_ili[df_ili['ILITOTAL'] != 'X']
    df_ili["ILITOTAL"] = df_ili["ILITOTAL"].astype(int)
    df_ili["TOTAL PATIENTS"] = df_ili["TOTAL PATIENTS"].astype(int)
    return df_ili

# %%
#Filter the 2 state data sets
df_ili_state = CreateILIDF(df_ilinet_selected_state)
df_clinical_state = CreateClinicalDF(df_clinical_labs_selected_state)

# %%
#get necessary clinical columns
df_clinical_state_grouped = pd.DataFrame(df_clinical_state.groupby(['REGION', 'WEEK'])[["TOTAL A", "TOTAL B", "TOTAL SPECIMENS"]].sum())
#Combine totals into one count of positives
df_clinical_state_grouped['TOTAL POSITIVE CLINICAL'] = df_clinical_state_grouped["TOTAL A"] + df_clinical_state_grouped["TOTAL B"]
#Drop original total columns that have been replaced
df_clinical_state_grouped = df_clinical_state_grouped.drop("TOTAL A", axis=1)
df_clinical_state_grouped = df_clinical_state_grouped.drop("TOTAL B", axis=1)
df_clinical_state_grouped = df_clinical_state_grouped.reset_index()

# %%
#get the necessary ili columns
df_ili_state_grouped = pd.DataFrame(df_ili_state.groupby(['REGION', 'WEEK'])[["ILITOTAL", "TOTAL PATIENTS"]].sum())
df_ili_state_grouped = df_ili_state_grouped.reset_index()

# %%
#merge the 2 state data sets
merged_state_df = pd.merge(df_ili_state_grouped, df_clinical_state_grouped, on = ['REGION', 'WEEK'], how = 'outer')
merged_state_df['PATIENT COUNT'] = merged_state_df['TOTAL PATIENTS'] + merged_state_df['TOTAL SPECIMENS']
merged_state_df['POSITIVE COUNT'] = merged_state_df['ILITOTAL'] + merged_state_df['TOTAL POSITIVE CLINICAL']
merged_state_df = merged_state_df.drop(['ILITOTAL' , 'TOTAL PATIENTS', 'TOTAL SPECIMENS', 'TOTAL POSITIVE CLINICAL'], axis=1)

# %%
def AssignMonth(df):
    #week numbers were estimated using https://calendar.online/calendar-weeks/2023
    #re-assign weeks to month and add to state_df as column
    #add month number to sort by month
    month_num = []
    month = list(df['WEEK'])
    for i in range(len(month)):
        if month[i] < 5:
            month[i] = 'January'
            month_num.append(1)
        elif month[i] < 9:
            month[i] = 'February'
            month_num.append(2)
        elif month[i] < 14:
            month[i] = 'March'
            month_num.append(3)
        elif month[i] < 18:
            month[i] = 'April'
            month_num.append(4)
        elif month[i] < 22:
            month[i] = 'May'
            month_num.append(5)
        elif month[i] < 27:
            month[i] = 'June'
            month_num.append(6)
        elif month[i] < 31:
            month[i] = 'July'
            month_num.append(7)
        elif month[i] < 36:
            month[i] = 'August'
            month_num.append(8)
        elif month[i] < 40:
            month[i] = 'September'
            month_num.append(9)
        elif month[i] < 44:
            month[i] = 'October'
            month_num.append(10)
        elif month[i] < 49:
            month[i] = 'November'
            month_num.append(11)
        elif month[i] < 53:
            month[i] = 'December'
            month_num.append(12)
    df['MONTH'] = month
    df['MONTH NUMBER'] = month_num
    df = df.drop('WEEK', axis=1)

    return df

# %%
#Calculate month values
merged_state_df = AssignMonth(merged_state_df)

# %%
#create final state df
#We should aknowledge some states aren't reporting every month
merged_state_df = pd.DataFrame(merged_state_df.groupby(['REGION', 'MONTH NUMBER', 'MONTH'])[['PATIENT COUNT','POSITIVE COUNT']].sum()).reset_index()
merged_state_df = merged_state_df.drop('MONTH NUMBER',axis=1)
merged_state_df['PERCENT POSITIVE'] = merged_state_df['POSITIVE COUNT'] / merged_state_df['PATIENT COUNT'] * 100

# %%
#Take the national dataframes and filter for year 2023 and filter/change column types of totals to int
df_ili_national = CreateILIDF(df_ilinet_selected_national)
df_clinical_national = CreateClinicalDF(df_clinical_labs_selected_national)

# %%
#get necessary clinical columns
df_clinical_national_grouped = pd.DataFrame(df_clinical_national.groupby(['WEEK'])[["TOTAL A", "TOTAL B", "TOTAL SPECIMENS"]].sum())
#Combine totals into one count of positives
df_clinical_national_grouped['TOTAL POSITIVE CLINICAL'] = df_clinical_national_grouped["TOTAL A"] + df_clinical_national_grouped["TOTAL B"]
#Drop original total columns that have been replaced
df_clinical_national_grouped = df_clinical_national_grouped.drop("TOTAL A", axis=1)
df_clinical_national_grouped = df_clinical_national_grouped.drop("TOTAL B", axis=1)
df_clinical_national_grouped = df_clinical_national_grouped.reset_index()

# %%
#get the necessary ili columns
df_ili_national_grouped = pd.DataFrame(df_ili_national.groupby(['WEEK'])[["ILITOTAL", "TOTAL PATIENTS"]].sum())
df_ili_national_grouped = df_ili_national_grouped.reset_index()

# %%
#merge the 2 national data sets
merged_national_df = pd.merge(df_ili_national_grouped, df_clinical_national_grouped, on = ['WEEK'], how = 'outer')
merged_national_df['PATIENT COUNT'] = merged_national_df['TOTAL PATIENTS'] + merged_national_df['TOTAL SPECIMENS']
merged_national_df['POSITIVE COUNT'] = merged_national_df['ILITOTAL'] + merged_national_df['TOTAL POSITIVE CLINICAL']
merged_national_df = merged_national_df.drop(['ILITOTAL' , 'TOTAL PATIENTS', 'TOTAL SPECIMENS', 'TOTAL POSITIVE CLINICAL'], axis=1)

# %%
#Calculate month values
merged_national_df = AssignMonth(merged_national_df)

# %%
#create final national df
merged_national_df = pd.DataFrame(merged_national_df.groupby(['MONTH NUMBER', 'MONTH'])[['PATIENT COUNT','POSITIVE COUNT']].sum()).reset_index()
merged_national_df = merged_national_df.drop('MONTH NUMBER',axis=1)
merged_national_df['PERCENT POSITIVE'] = merged_national_df['POSITIVE COUNT'] / merged_national_df['PATIENT COUNT'] * 100

# %%
#Make 2 csv fils
merged_state_df.to_csv('combined_state_data.csv')
merged_national_df.to_csv('combined_national_data.csv')

# %% [markdown]
# ## Database Creation

# %%
# !mongoimport --type csv -d flu -c combined_national --headerline --drop Resources/combined_national_data.csv
# !mongoimport --type csv -d flu -c combined_state --headerline --drop Resources/combined_state_data.csv
# Out:
# 'mongoimport' is not recognized as an internal or external command,
# operable program or batch file.
# 'mongoimport' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Import dependencies
from pymongo import MongoClient

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that the "flu" database is in MongoDB
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'flu', 'local', 'uk_food']

# %%
# assign the database to a variable name
db = mongo['flu']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['combined_national', 'combined_state']

# %%
# review a document in the combined_national collection
print(db.combined_national.find_one())
# Out:
# {'_id': ObjectId('65b87e26846c55748df464b0'), '': 0, 'MONTH': 'January', 'PATIENT COUNT': 9221974, 'POSITIVE COUNT': 296436, 'PERCENT POSITIVE': 3.2144527841869865}

# %%
# review a document in the combined_state collection
print(db.combined_state.find_one())
# Out:
# {'_id': ObjectId('65b87e57846c55748df464bd'), '': 0, 'REGION': 'Alabama', 'MONTH': 'January', 'PATIENT COUNT': 190817.0, 'POSITIVE COUNT': 5460.0, 'PERCENT POSITIVE': 2.8613802753423436}

# %%
# assign each collection to a variable
combined_state = db['combined_state']
combined_national = db['combined_national']

# %% [markdown]
# ## Data Retrieval

# %% [markdown]
# Connect to MongoDB:
# establishing a connection to MongoDB database using the pymongo library.

# %%
from pymongo import MongoClient


# Establish a connection to the MongoDB server
client = MongoClient(port=27017)

# Select the database
db = client['flu-db']

# %% [markdown]
# Read Data into a Pandas DataFrame

# %%
for document in combined_state.find():
    print(document)
# Out:
# {'_id': ObjectId('65b87e57846c55748df464bd'), '': 0, 'REGION': 'Alabama', 'MONTH': 'January', 'PATIENT COUNT': 190817.0, 'POSITIVE COUNT': 5460.0, 'PERCENT POSITIVE': 2.8613802753423436}
# {'_id': ObjectId('65b87e57846c55748df464be'), '': 1, 'REGION': 'Alabama', 'MONTH': 'February', 'PATIENT COUNT': 197516.0, 'POSITIVE COUNT': 5086.0, 'PERCENT POSITIVE': 2.5749812673403674}
# {'_id': ObjectId('65b87e57846c55748df464bf'), '': 2, 'REGION': 'Alabama', 'MONTH': 'March', 'PATIENT COUNT': 231552.0, 'POSITIVE COUNT': 4296.0, 'PERCENT POSITIVE': 1.8553067993366499}
# {'_id': ObjectId('65b87e57846c55748df464c0'), '': 3, 'REGION': 'Alabama', 'MONTH': 'April', 'PATIENT COUNT': 189737.0, 'POSITIVE COUNT': 3023.0, 'PERCENT POSITIVE': 1.5932580361236868}
# {'_id': ObjectId('65b87e57846c55748df464c1'), '': 4, 'REGION': 'Alabama', 'MONTH': 'May', 'PATIENT COUNT': 182084.0, 'POSITIVE COUNT': 2896.0, 'PERCENT POSITIVE': 1.59047472595066}
# {'_id': ObjectId('65b87e57846c55748df464c2'), '': 5, 'REGION': 'Alabama', 'MONTH': 'June', 'PATIENT COUNT': 226648.0, 'POSITIVE COUNT': 2635.0, 'PERCENT POSITIVE': 1.16259574317885}
# {'_id': ObjectId('65b87e57846c55748df464c3'), '': 6, 'REGION': 'Alabama', 'MONTH': 'July', 'PATIENT COUNT': 184067.0, 'POSITIVE COUNT': 1885.0, 'PERCENT POSITIVE': 1.024083621724698}
# {'_id': ObjectId('65b87e57846c55748df464c4'), '': 7, 'REGION': 'Alabama', 'MONTH': 'August', 'PATIENT COUNT': 256072.0, 'POSITIVE COUNT': 5484.0, 'PERCENT POSITIVE': 2.141585179168359}
# {'_id': ObjectId('65b87e57846c55748df464c5'), '': 8, 'REGION': 'Alabama', 'MONTH': 'September', 'PATIENT COUNT': 184882.0, 'POSITIVE COUNT': 4476.0, 'PERCENT POSITIVE': 2.421003667203946}
# {'_id': ObjectId('65b87e57846c55748df464c6'), '': 9, 'REGION': 'Alabama', 'MONTH': 'October', 'PATIENT COUNT': 169917.0, 'POSITIVE COUNT': 4601.0, 'PERCENT POSITIVE': 2.707792628165516}
# {'_id': ObjectId('65b87e57846c55748df464c7'), '': 10, 'REGION': 'Alabama', 'MONTH': 'November', 'PATIENT COUNT': 220559.0, 'POSITIVE COUNT': 11099.0, 'PERCENT POSITIVE': 5.032213602709479}
# {'_id': ObjectId('65b87e57846c55748df464c8'), '': 11, 'REGION': 'Alabama', 'MONTH': 'December', 'PATIENT COUNT': 187854.0, 'POSITIVE COUNT': 16972.0, 'PERCENT POSITIVE': 9.034675865299647}
# {'_id': ObjectId('65b87e57846c55748df464c9'), '': 12, 'REGION': 'Alaska', 'MONTH': 'January', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464ca'), '': 13, 'REGION': 'Alaska', 'MONTH': 'February', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464cb'), '': 14, 'REGION': 'Alaska', 'MONTH': 'March', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464cc'), '': 15, 'REGION': 'Alaska', 'MONTH': 'April', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464cd'), '': 16, 'REGION': 'Alaska', 'MONTH': 'May', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464ce'), '': 17, 'REGION': 'Alaska', 'MONTH': 'June', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464cf'), '': 18, 'REGION': 'Alaska', 'MONTH': 'July', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464d0'), '': 19, 'REGION': 'Alaska', 'MONTH': 'August', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464d1'), '': 20, 'REGION': 'Alaska', 'MONTH': 'September', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464d2'), '': 21, 'REGION': 'Alaska', 'MONTH': 'October', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464d3'), '': 22, 'REGION': 'Alaska', 'MONTH': 'November', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464d4'), '': 23, 'REGION': 'Alaska', 'MONTH': 'December', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df464d5'), '': 24, 'REGION': 'Arizona', 'MONTH': 'January', 'PATIENT COUNT': 90321.0, 'POSITIVE COUNT': 1674.0, 'PERCENT POSITIVE': 1.8533895771747435}
# {'_id': ObjectId('65b87e57846c55748df464d6'), '': 25, 'REGION': 'Arizona', 'MONTH': 'February', 'PATIENT COUNT': 90200.0, 'POSITIVE COUNT': 1566.0, 'PERCENT POSITIVE': 1.7361419068736141}
# {'_id': ObjectId('65b87e57846c55748df464d7'), '': 26, 'REGION': 'Arizona', 'MONTH': 'March', 'PATIENT COUNT': 120751.0, 'POSITIVE COUNT': 1735.0, 'PERCENT POSITIVE': 1.4368411027651944}
# {'_id': ObjectId('65b87e57846c55748df464d8'), '': 27, 'REGION': 'Arizona', 'MONTH': 'April', 'PATIENT COUNT': 91916.0, 'POSITIVE COUNT': 1207.0, 'PERCENT POSITIVE': 1.3131554897950304}
# {'_id': ObjectId('65b87e57846c55748df464d9'), '': 28, 'REGION': 'Arizona', 'MONTH': 'May', 'PATIENT COUNT': 88806.0, 'POSITIVE COUNT': 1214.0, 'PERCENT POSITIVE': 1.3670247505799158}
# {'_id': ObjectId('65b87e57846c55748df464da'), '': 29, 'REGION': 'Arizona', 'MONTH': 'June', 'PATIENT COUNT': 105584.0, 'POSITIVE COUNT': 989.0, 'PERCENT POSITIVE': 0.9366949537808759}
# {'_id': ObjectId('65b87e57846c55748df464db'), '': 30, 'REGION': 'Arizona', 'MONTH': 'July', 'PATIENT COUNT': 74019.0, 'POSITIVE COUNT': 465.0, 'PERCENT POSITIVE': 0.6282170793985328}
# {'_id': ObjectId('65b87e57846c55748df464dc'), '': 31, 'REGION': 'Arizona', 'MONTH': 'August', 'PATIENT COUNT': 106014.0, 'POSITIVE COUNT': 893.0, 'PERCENT POSITIVE': 0.8423415775274964}
# {'_id': ObjectId('65b87e57846c55748df464dd'), '': 32, 'REGION': 'Arizona', 'MONTH': 'September', 'PATIENT COUNT': 130526.0, 'POSITIVE COUNT': 880.0, 'PERCENT POSITIVE': 0.6741951795044665}
# {'_id': ObjectId('65b87e57846c55748df464de'), '': 33, 'REGION': 'Arizona', 'MONTH': 'October', 'PATIENT COUNT': 299979.0, 'POSITIVE COUNT': 5619.0, 'PERCENT POSITIVE': 1.8731311191783426}
# {'_id': ObjectId('65b87e57846c55748df464df'), '': 34, 'REGION': 'Arizona', 'MONTH': 'November', 'PATIENT COUNT': 375726.0, 'POSITIVE COUNT': 10595.0, 'PERCENT POSITIVE': 2.8198740571586742}
# {'_id': ObjectId('65b87e57846c55748df464e0'), '': 35, 'REGION': 'Arizona', 'MONTH': 'December', 'PATIENT COUNT': 323796.0, 'POSITIVE COUNT': 16330.0, 'PERCENT POSITIVE': 5.043298867187983}
# {'_id': ObjectId('65b87e57846c55748df464e1'), '': 36, 'REGION': 'Arkansas', 'MONTH': 'January', 'PATIENT COUNT': 62569.0, 'POSITIVE COUNT': 1643.0, 'PERCENT POSITIVE': 2.6259010052901597}
# {'_id': ObjectId('65b87e57846c55748df464e2'), '': 37, 'REGION': 'Arkansas', 'MONTH': 'February', 'PATIENT COUNT': 61237.0, 'POSITIVE COUNT': 1294.0, 'PERCENT POSITIVE': 2.1131015562486732}
# {'_id': ObjectId('65b87e57846c55748df464e3'), '': 38, 'REGION': 'Arkansas', 'MONTH': 'March', 'PATIENT COUNT': 76457.0, 'POSITIVE COUNT': 1323.0, 'PERCENT POSITIVE': 1.7303843990739893}
# {'_id': ObjectId('65b87e57846c55748df464e4'), '': 39, 'REGION': 'Arkansas', 'MONTH': 'April', 'PATIENT COUNT': 59830.0, 'POSITIVE COUNT': 748.0, 'PERCENT POSITIVE': 1.2502089252883168}
# {'_id': ObjectId('65b87e57846c55748df464e5'), '': 40, 'REGION': 'Arkansas', 'MONTH': 'May', 'PATIENT COUNT': 60473.0, 'POSITIVE COUNT': 633.0, 'PERCENT POSITIVE': 1.0467481355315595}
# {'_id': ObjectId('65b87e57846c55748df464e6'), '': 41, 'REGION': 'Arkansas', 'MONTH': 'June', 'PATIENT COUNT': 70571.0, 'POSITIVE COUNT': 521.0, 'PERCENT POSITIVE': 0.7382635926938828}
# {'_id': ObjectId('65b87e57846c55748df464e7'), '': 42, 'REGION': 'Arkansas', 'MONTH': 'July', 'PATIENT COUNT': 56279.0, 'POSITIVE COUNT': 322.0, 'PERCENT POSITIVE': 0.5721494696067805}
# {'_id': ObjectId('65b87e57846c55748df464e8'), '': 43, 'REGION': 'Arkansas', 'MONTH': 'August', 'PATIENT COUNT': 75855.0, 'POSITIVE COUNT': 826.0, 'PERCENT POSITIVE': 1.0889196493309603}
# {'_id': ObjectId('65b87e57846c55748df464e9'), '': 44, 'REGION': 'Arkansas', 'MONTH': 'September', 'PATIENT COUNT': 62714.0, 'POSITIVE COUNT': 1055.0, 'PERCENT POSITIVE': 1.6822400102050579}
# {'_id': ObjectId('65b87e57846c55748df464ea'), '': 45, 'REGION': 'Arkansas', 'MONTH': 'October', 'PATIENT COUNT': 64314.0, 'POSITIVE COUNT': 1245.0, 'PERCENT POSITIVE': 1.9358149081070994}
# {'_id': ObjectId('65b87e57846c55748df464eb'), '': 46, 'REGION': 'Arkansas', 'MONTH': 'November', 'PATIENT COUNT': 81841.0, 'POSITIVE COUNT': 2574.0, 'PERCENT POSITIVE': 3.145122860180105}
# {'_id': ObjectId('65b87e57846c55748df464ec'), '': 47, 'REGION': 'Arkansas', 'MONTH': 'December', 'PATIENT COUNT': 63917.0, 'POSITIVE COUNT': 3234.0, 'PERCENT POSITIVE': 5.059686781294491}
# {'_id': ObjectId('65b87e57846c55748df464ed'), '': 48, 'REGION': 'California', 'MONTH': 'January', 'PATIENT COUNT': 1136788.0, 'POSITIVE COUNT': 44136.0, 'PERCENT POSITIVE': 3.8825181124360917}
# {'_id': ObjectId('65b87e57846c55748df464ee'), '': 49, 'REGION': 'California', 'MONTH': 'February', 'PATIENT COUNT': 1192553.0, 'POSITIVE COUNT': 41647.0, 'PERCENT POSITIVE': 3.4922556901035002}
# {'_id': ObjectId('65b87e57846c55748df464ef'), '': 50, 'REGION': 'California', 'MONTH': 'March', 'PATIENT COUNT': 1476692.0, 'POSITIVE COUNT': 48399.0, 'PERCENT POSITIVE': 3.2775284216343015}
# {'_id': ObjectId('65b87e57846c55748df464f0'), '': 51, 'REGION': 'California', 'MONTH': 'April', 'PATIENT COUNT': 1118029.0, 'POSITIVE COUNT': 32329.0, 'PERCENT POSITIVE': 2.891606568344828}
# {'_id': ObjectId('65b87e57846c55748df464f1'), '': 52, 'REGION': 'California', 'MONTH': 'May', 'PATIENT COUNT': 1144752.0, 'POSITIVE COUNT': 32399.0, 'PERCENT POSITIVE': 2.8302199952478793}
# {'_id': ObjectId('65b87e57846c55748df464f2'), '': 53, 'REGION': 'California', 'MONTH': 'June', 'PATIENT COUNT': 1320240.0, 'POSITIVE COUNT': 35377.0, 'PERCENT POSITIVE': 2.67958855965582}
# {'_id': ObjectId('65b87e57846c55748df464f3'), '': 54, 'REGION': 'California', 'MONTH': 'July', 'PATIENT COUNT': 1011583.0, 'POSITIVE COUNT': 20005.0, 'PERCENT POSITIVE': 1.9775935340945825}
# {'_id': ObjectId('65b87e57846c55748df464f4'), '': 55, 'REGION': 'California', 'MONTH': 'August', 'PATIENT COUNT': 1322616.0, 'POSITIVE COUNT': 26382.0, 'PERCENT POSITIVE': 1.9946832640766483}
# {'_id': ObjectId('65b87e57846c55748df464f5'), '': 56, 'REGION': 'California', 'MONTH': 'September', 'PATIENT COUNT': 1065204.0, 'POSITIVE COUNT': 25856.0, 'PERCENT POSITIVE': 2.427328474170206}
# {'_id': ObjectId('65b87e57846c55748df464f6'), '': 57, 'REGION': 'California', 'MONTH': 'October', 'PATIENT COUNT': 1087839.0, 'POSITIVE COUNT': 32594.0, 'PERCENT POSITIVE': 2.996215432614569}
# {'_id': ObjectId('65b87e57846c55748df464f7'), '': 58, 'REGION': 'California', 'MONTH': 'November', 'PATIENT COUNT': 1423121.0, 'POSITIVE COUNT': 68098.0, 'PERCENT POSITIVE': 4.785116655576019}
# {'_id': ObjectId('65b87e57846c55748df464f8'), '': 59, 'REGION': 'California', 'MONTH': 'December', 'PATIENT COUNT': 1192896.0, 'POSITIVE COUNT': 90128.0, 'PERCENT POSITIVE': 7.555394602714738}
# {'_id': ObjectId('65b87e57846c55748df464f9'), '': 60, 'REGION': 'Colorado', 'MONTH': 'January', 'PATIENT COUNT': 182303.0, 'POSITIVE COUNT': 6593.0, 'PERCENT POSITIVE': 3.6165065851905895}
# {'_id': ObjectId('65b87e57846c55748df464fa'), '': 61, 'REGION': 'Colorado', 'MONTH': 'February', 'PATIENT COUNT': 202949.0, 'POSITIVE COUNT': 6511.0, 'PERCENT POSITIVE': 3.208195162331423}
# {'_id': ObjectId('65b87e57846c55748df464fb'), '': 62, 'REGION': 'Colorado', 'MONTH': 'March', 'PATIENT COUNT': 257897.0, 'POSITIVE COUNT': 7707.0, 'PERCENT POSITIVE': 2.988402346673284}
# {'_id': ObjectId('65b87e57846c55748df464fc'), '': 63, 'REGION': 'Colorado', 'MONTH': 'April', 'PATIENT COUNT': 205435.0, 'POSITIVE COUNT': 5238.0, 'PERCENT POSITIVE': 2.5497115876067853}
# {'_id': ObjectId('65b87e57846c55748df464fd'), '': 64, 'REGION': 'Colorado', 'MONTH': 'May', 'PATIENT COUNT': 205394.0, 'POSITIVE COUNT': 4542.0, 'PERCENT POSITIVE': 2.211359630758445}
# {'_id': ObjectId('65b87e57846c55748df464fe'), '': 65, 'REGION': 'Colorado', 'MONTH': 'June', 'PATIENT COUNT': 241979.0, 'POSITIVE COUNT': 3437.0, 'PERCENT POSITIVE': 1.4203711892354296}
# {'_id': ObjectId('65b87e57846c55748df464ff'), '': 66, 'REGION': 'Colorado', 'MONTH': 'July', 'PATIENT COUNT': 193914.0, 'POSITIVE COUNT': 1774.0, 'PERCENT POSITIVE': 0.9148385366708953}
# {'_id': ObjectId('65b87e57846c55748df46500'), '': 67, 'REGION': 'Colorado', 'MONTH': 'August', 'PATIENT COUNT': 255488.0, 'POSITIVE COUNT': 3083.0, 'PERCENT POSITIVE': 1.2067102955911824}
# {'_id': ObjectId('65b87e57846c55748df46501'), '': 68, 'REGION': 'Colorado', 'MONTH': 'September', 'PATIENT COUNT': 203677.0, 'POSITIVE COUNT': 3818.0, 'PERCENT POSITIVE': 1.8745366438036697}
# {'_id': ObjectId('65b87e57846c55748df46502'), '': 69, 'REGION': 'Colorado', 'MONTH': 'October', 'PATIENT COUNT': 199763.0, 'POSITIVE COUNT': 4836.0, 'PERCENT POSITIVE': 2.4208687294443916}
# {'_id': ObjectId('65b87e57846c55748df46503'), '': 70, 'REGION': 'Colorado', 'MONTH': 'November', 'PATIENT COUNT': 257004.0, 'POSITIVE COUNT': 11563.0, 'PERCENT POSITIVE': 4.499151764174877}
# {'_id': ObjectId('65b87e57846c55748df46504'), '': 71, 'REGION': 'Colorado', 'MONTH': 'December', 'PATIENT COUNT': 210213.0, 'POSITIVE COUNT': 16518.0, 'PERCENT POSITIVE': 7.857744287936522}
# {'_id': ObjectId('65b87e57846c55748df46505'), '': 72, 'REGION': 'Connecticut', 'MONTH': 'January', 'PATIENT COUNT': 179509.0, 'POSITIVE COUNT': 4922.0, 'PERCENT POSITIVE': 2.741923803263346}
# {'_id': ObjectId('65b87e57846c55748df46506'), '': 73, 'REGION': 'Connecticut', 'MONTH': 'February', 'PATIENT COUNT': 179811.0, 'POSITIVE COUNT': 3436.0, 'PERCENT POSITIVE': 1.9108953289843225}
# {'_id': ObjectId('65b87e57846c55748df46507'), '': 74, 'REGION': 'Connecticut', 'MONTH': 'March', 'PATIENT COUNT': 220485.0, 'POSITIVE COUNT': 3909.0, 'PERCENT POSITIVE': 1.772909721749779}
# {'_id': ObjectId('65b87e57846c55748df46508'), '': 75, 'REGION': 'Connecticut', 'MONTH': 'April', 'PATIENT COUNT': 177791.0, 'POSITIVE COUNT': 2622.0, 'PERCENT POSITIVE': 1.4747653143297468}
# {'_id': ObjectId('65b87e57846c55748df46509'), '': 76, 'REGION': 'Connecticut', 'MONTH': 'May', 'PATIENT COUNT': 177499.0, 'POSITIVE COUNT': 2284.0, 'PERCENT POSITIVE': 1.28676781277641}
# {'_id': ObjectId('65b87e57846c55748df4650a'), '': 77, 'REGION': 'Connecticut', 'MONTH': 'June', 'PATIENT COUNT': 212055.0, 'POSITIVE COUNT': 2176.0, 'PERCENT POSITIVE': 1.026148876470727}
# {'_id': ObjectId('65b87e57846c55748df4650b'), '': 78, 'REGION': 'Connecticut', 'MONTH': 'July', 'PATIENT COUNT': 166867.0, 'POSITIVE COUNT': 1291.0, 'PERCENT POSITIVE': 0.773670048601581}
# {'_id': ObjectId('65b87e57846c55748df4650c'), '': 79, 'REGION': 'Connecticut', 'MONTH': 'August', 'PATIENT COUNT': 201910.0, 'POSITIVE COUNT': 1881.0, 'PERCENT POSITIVE': 0.931603189539894}
# {'_id': ObjectId('65b87e57846c55748df4650d'), '': 80, 'REGION': 'Connecticut', 'MONTH': 'September', 'PATIENT COUNT': 174785.0, 'POSITIVE COUNT': 2576.0, 'PERCENT POSITIVE': 1.4738106816946535}
# {'_id': ObjectId('65b87e57846c55748df4650e'), '': 81, 'REGION': 'Connecticut', 'MONTH': 'October', 'PATIENT COUNT': 177785.0, 'POSITIVE COUNT': 3043.0, 'PERCENT POSITIVE': 1.7116179655201507}
# {'_id': ObjectId('65b87e57846c55748df4650f'), '': 82, 'REGION': 'Connecticut', 'MONTH': 'November', 'PATIENT COUNT': 227957.0, 'POSITIVE COUNT': 6114.0, 'PERCENT POSITIVE': 2.6820847791469444}
# {'_id': ObjectId('65b87e57846c55748df46510'), '': 83, 'REGION': 'Connecticut', 'MONTH': 'December', 'PATIENT COUNT': 191893.0, 'POSITIVE COUNT': 7977.0, 'PERCENT POSITIVE': 4.1570041637787725}
# {'_id': ObjectId('65b87e57846c55748df46511'), '': 84, 'REGION': 'Delaware', 'MONTH': 'January', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46512'), '': 85, 'REGION': 'Delaware', 'MONTH': 'February', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46513'), '': 86, 'REGION': 'Delaware', 'MONTH': 'March', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46514'), '': 87, 'REGION': 'Delaware', 'MONTH': 'April', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46515'), '': 88, 'REGION': 'Delaware', 'MONTH': 'May', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46516'), '': 89, 'REGION': 'Delaware', 'MONTH': 'June', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46517'), '': 90, 'REGION': 'Delaware', 'MONTH': 'July', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46518'), '': 91, 'REGION': 'Delaware', 'MONTH': 'August', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46519'), '': 92, 'REGION': 'Delaware', 'MONTH': 'September', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df4651a'), '': 93, 'REGION': 'Delaware', 'MONTH': 'October', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df4651b'), '': 94, 'REGION': 'Delaware', 'MONTH': 'November', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df4651c'), '': 95, 'REGION': 'Delaware', 'MONTH': 'December', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df4651d'), '': 96, 'REGION': 'District of Columbia', 'MONTH': 'January', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df4651e'), '': 97, 'REGION': 'District of Columbia', 'MONTH': 'February', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df4651f'), '': 98, 'REGION': 'District of Columbia', 'MONTH': 'March', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46520'), '': 99, 'REGION': 'District of Columbia', 'MONTH': 'April', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46521'), '': 100, 'REGION': 'District of Columbia', 'MONTH': 'May', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46522'), '': 101, 'REGION': 'District of Columbia', 'MONTH': 'June', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46523'), '': 102, 'REGION': 'District of Columbia', 'MONTH': 'July', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46524'), '': 103, 'REGION': 'District of Columbia', 'MONTH': 'August', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46525'), '': 104, 'REGION': 'District of Columbia', 'MONTH': 'September', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46526'), '': 105, 'REGION': 'District of Columbia', 'MONTH': 'October', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46527'), '': 106, 'REGION': 'District of Columbia', 'MONTH': 'November', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46528'), '': 107, 'REGION': 'District of Columbia', 'MONTH': 'December', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46529'), '': 108, 'REGION': 'Florida', 'MONTH': 'January', 'PATIENT COUNT': 1043918.0, 'POSITIVE COUNT': 44605.0, 'PERCENT POSITIVE': 4.272845185158221}
# {'_id': ObjectId('65b87e57846c55748df4652a'), '': 109, 'REGION': 'Florida', 'MONTH': 'February', 'PATIENT COUNT': 1052191.0, 'POSITIVE COUNT': 37107.0, 'PERCENT POSITIVE': 3.5266410756222015}
# {'_id': ObjectId('65b87e57846c55748df4652b'), '': 110, 'REGION': 'Florida', 'MONTH': 'March', 'PATIENT COUNT': 1318548.0, 'POSITIVE COUNT': 39722.0, 'PERCENT POSITIVE': 3.0125562361021365}
# {'_id': ObjectId('65b87e57846c55748df4652c'), '': 111, 'REGION': 'Florida', 'MONTH': 'April', 'PATIENT COUNT': 1026364.0, 'POSITIVE COUNT': 29360.0, 'PERCENT POSITIVE': 2.8605835746382375}
# {'_id': ObjectId('65b87e57846c55748df4652d'), '': 112, 'REGION': 'Florida', 'MONTH': 'May', 'PATIENT COUNT': 1001468.0, 'POSITIVE COUNT': 29064.0, 'PERCENT POSITIVE': 2.9021396589806163}
# {'_id': ObjectId('65b87e57846c55748df4652e'), '': 113, 'REGION': 'Florida', 'MONTH': 'June', 'PATIENT COUNT': 1193511.0, 'POSITIVE COUNT': 30356.0, 'PERCENT POSITIVE': 2.543420211460137}
# {'_id': ObjectId('65b87e57846c55748df4652f'), '': 114, 'REGION': 'Florida', 'MONTH': 'July', 'PATIENT COUNT': 943509.0, 'POSITIVE COUNT': 20391.0, 'PERCENT POSITIVE': 2.1611876516281243}
# {'_id': ObjectId('65b87e57846c55748df46530'), '': 115, 'REGION': 'Florida', 'MONTH': 'August', 'PATIENT COUNT': 1227387.0, 'POSITIVE COUNT': 36049.0, 'PERCENT POSITIVE': 2.9370524537085694}
# {'_id': ObjectId('65b87e57846c55748df46531'), '': 116, 'REGION': 'Florida', 'MONTH': 'September', 'PATIENT COUNT': 1006040.0, 'POSITIVE COUNT': 33715.0, 'PERCENT POSITIVE': 3.351258399268419}
# {'_id': ObjectId('65b87e57846c55748df46532'), '': 117, 'REGION': 'Florida', 'MONTH': 'October', 'PATIENT COUNT': 1021948.0, 'POSITIVE COUNT': 43714.0, 'PERCENT POSITIVE': 4.277517055662323}
# {'_id': ObjectId('65b87e57846c55748df46533'), '': 118, 'REGION': 'Florida', 'MONTH': 'November', 'PATIENT COUNT': 1290956.0, 'POSITIVE COUNT': 68139.0, 'PERCENT POSITIVE': 5.278181440730745}
# {'_id': ObjectId('65b87e57846c55748df46534'), '': 119, 'REGION': 'Florida', 'MONTH': 'December', 'PATIENT COUNT': 1042869.0, 'POSITIVE COUNT': 63869.0, 'PERCENT POSITIVE': 6.124355024456571}
# {'_id': ObjectId('65b87e57846c55748df46535'), '': 120, 'REGION': 'Georgia', 'MONTH': 'January', 'PATIENT COUNT': 311475.0, 'POSITIVE COUNT': 9520.0, 'PERCENT POSITIVE': 3.056425074243519}
# {'_id': ObjectId('65b87e57846c55748df46536'), '': 121, 'REGION': 'Georgia', 'MONTH': 'February', 'PATIENT COUNT': 322413.0, 'POSITIVE COUNT': 9332.0, 'PERCENT POSITIVE': 2.8944242322735123}
# {'_id': ObjectId('65b87e57846c55748df46537'), '': 122, 'REGION': 'Georgia', 'MONTH': 'March', 'PATIENT COUNT': 390891.0, 'POSITIVE COUNT': 9567.0, 'PERCENT POSITIVE': 2.447485360369003}
# {'_id': ObjectId('65b87e57846c55748df46538'), '': 123, 'REGION': 'Georgia', 'MONTH': 'April', 'PATIENT COUNT': 317822.0, 'POSITIVE COUNT': 6759.0, 'PERCENT POSITIVE': 2.1266620938764467}
# {'_id': ObjectId('65b87e57846c55748df46539'), '': 124, 'REGION': 'Georgia', 'MONTH': 'May', 'PATIENT COUNT': 326386.0, 'POSITIVE COUNT': 7215.0, 'PERCENT POSITIVE': 2.210572757409938}
# {'_id': ObjectId('65b87e57846c55748df4653a'), '': 125, 'REGION': 'Georgia', 'MONTH': 'June', 'PATIENT COUNT': 379644.0, 'POSITIVE COUNT': 6516.0, 'PERCENT POSITIVE': 1.7163447861680943}
# {'_id': ObjectId('65b87e57846c55748df4653b'), '': 126, 'REGION': 'Georgia', 'MONTH': 'July', 'PATIENT COUNT': 307049.0, 'POSITIVE COUNT': 4201.0, 'PERCENT POSITIVE': 1.368185533905012}
# {'_id': ObjectId('65b87e57846c55748df4653c'), '': 127, 'REGION': 'Georgia', 'MONTH': 'August', 'PATIENT COUNT': 410947.0, 'POSITIVE COUNT': 11600.0, 'PERCENT POSITIVE': 2.8227484322795884}
# {'_id': ObjectId('65b87e57846c55748df4653d'), '': 128, 'REGION': 'Georgia', 'MONTH': 'September', 'PATIENT COUNT': 329142.0, 'POSITIVE COUNT': 10542.0, 'PERCENT POSITIVE': 3.2028729241482403}
# {'_id': ObjectId('65b87e57846c55748df4653e'), '': 129, 'REGION': 'Georgia', 'MONTH': 'October', 'PATIENT COUNT': 336416.0, 'POSITIVE COUNT': 12332.0, 'PERCENT POSITIVE': 3.6656996100066586}
# {'_id': ObjectId('65b87e57846c55748df4653f'), '': 130, 'REGION': 'Georgia', 'MONTH': 'November', 'PATIENT COUNT': 432253.0, 'POSITIVE COUNT': 22607.0, 'PERCENT POSITIVE': 5.230038889261613}
# {'_id': ObjectId('65b87e57846c55748df46540'), '': 131, 'REGION': 'Georgia', 'MONTH': 'December', 'PATIENT COUNT': 362448.0, 'POSITIVE COUNT': 33174.0, 'PERCENT POSITIVE': 9.152761223678983}
# {'_id': ObjectId('65b87e57846c55748df46541'), '': 132, 'REGION': 'Hawaii', 'MONTH': 'January', 'PATIENT COUNT': 136770.0, 'POSITIVE COUNT': 4756.0, 'PERCENT POSITIVE': 3.4773707684433717}
# {'_id': ObjectId('65b87e57846c55748df46542'), '': 133, 'REGION': 'Hawaii', 'MONTH': 'February', 'PATIENT COUNT': 139897.0, 'POSITIVE COUNT': 3958.0, 'PERCENT POSITIVE': 2.82922435792047}
# {'_id': ObjectId('65b87e57846c55748df46543'), '': 134, 'REGION': 'Hawaii', 'MONTH': 'March', 'PATIENT COUNT': 171787.0, 'POSITIVE COUNT': 4265.0, 'PERCENT POSITIVE': 2.4827257010134645}
# {'_id': ObjectId('65b87e57846c55748df46544'), '': 135, 'REGION': 'Hawaii', 'MONTH': 'April', 'PATIENT COUNT': 145062.0, 'POSITIVE COUNT': 3583.0, 'PERCENT POSITIVE': 2.4699783540830818}
# {'_id': ObjectId('65b87e57846c55748df46545'), '': 136, 'REGION': 'Hawaii', 'MONTH': 'May', 'PATIENT COUNT': 141672.0, 'POSITIVE COUNT': 3120.0, 'PERCENT POSITIVE': 2.2022700321870237}
# {'_id': ObjectId('65b87e57846c55748df46546'), '': 137, 'REGION': 'Hawaii', 'MONTH': 'June', 'PATIENT COUNT': 165802.0, 'POSITIVE COUNT': 3276.0, 'PERCENT POSITIVE': 1.9758507135016465}
# {'_id': ObjectId('65b87e57846c55748df46547'), '': 138, 'REGION': 'Hawaii', 'MONTH': 'July', 'PATIENT COUNT': 131897.0, 'POSITIVE COUNT': 2621.0, 'PERCENT POSITIVE': 1.987156644957808}
# {'_id': ObjectId('65b87e57846c55748df46548'), '': 139, 'REGION': 'Hawaii', 'MONTH': 'August', 'PATIENT COUNT': 176322.0, 'POSITIVE COUNT': 4422.0, 'PERCENT POSITIVE': 2.507911661619083}
# {'_id': ObjectId('65b87e57846c55748df46549'), '': 140, 'REGION': 'Hawaii', 'MONTH': 'September', 'PATIENT COUNT': 140016.0, 'POSITIVE COUNT': 4274.0, 'PERCENT POSITIVE': 3.052508284767455}
# {'_id': ObjectId('65b87e57846c55748df4654a'), '': 141, 'REGION': 'Hawaii', 'MONTH': 'October', 'PATIENT COUNT': 143750.0, 'POSITIVE COUNT': 4794.0, 'PERCENT POSITIVE': 3.3349565217391306}
# {'_id': ObjectId('65b87e57846c55748df4654b'), '': 142, 'REGION': 'Hawaii', 'MONTH': 'November', 'PATIENT COUNT': 170409.0, 'POSITIVE COUNT': 6530.0, 'PERCENT POSITIVE': 3.8319572323058058}
# {'_id': ObjectId('65b87e57846c55748df4654c'), '': 143, 'REGION': 'Hawaii', 'MONTH': 'December', 'PATIENT COUNT': 134933.0, 'POSITIVE COUNT': 5932.0, 'PERCENT POSITIVE': 4.3962559196045445}
# {'_id': ObjectId('65b87e57846c55748df4654d'), '': 144, 'REGION': 'Idaho', 'MONTH': 'January', 'PATIENT COUNT': 36812.0, 'POSITIVE COUNT': 792.0, 'PERCENT POSITIVE': 2.151472345974139}
# {'_id': ObjectId('65b87e57846c55748df4654e'), '': 145, 'REGION': 'Idaho', 'MONTH': 'February', 'PATIENT COUNT': 36908.0, 'POSITIVE COUNT': 475.0, 'PERCENT POSITIVE': 1.2869838517394603}
# {'_id': ObjectId('65b87e57846c55748df4654f'), '': 146, 'REGION': 'Idaho', 'MONTH': 'March', 'PATIENT COUNT': 45015.0, 'POSITIVE COUNT': 515.0, 'PERCENT POSITIVE': 1.1440630900810842}
# {'_id': ObjectId('65b87e57846c55748df46550'), '': 147, 'REGION': 'Idaho', 'MONTH': 'April', 'PATIENT COUNT': 25895.0, 'POSITIVE COUNT': 263.0, 'PERCENT POSITIVE': 1.0156400849584861}
# {'_id': ObjectId('65b87e57846c55748df46551'), '': 148, 'REGION': 'Idaho', 'MONTH': 'May', 'PATIENT COUNT': 8625.0, 'POSITIVE COUNT': 76.0, 'PERCENT POSITIVE': 0.8811594202898552}
# {'_id': ObjectId('65b87e57846c55748df46552'), '': 149, 'REGION': 'Idaho', 'MONTH': 'June', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46553'), '': 150, 'REGION': 'Idaho', 'MONTH': 'July', 'PATIENT COUNT': 40634.0, 'POSITIVE COUNT': 183.0, 'PERCENT POSITIVE': 0.4503617660087611}
# {'_id': ObjectId('65b87e57846c55748df46554'), '': 151, 'REGION': 'Idaho', 'MONTH': 'August', 'PATIENT COUNT': 50551.0, 'POSITIVE COUNT': 262.0, 'PERCENT POSITIVE': 0.5182884611580384}
# {'_id': ObjectId('65b87e57846c55748df46555'), '': 152, 'REGION': 'Idaho', 'MONTH': 'September', 'PATIENT COUNT': 41647.0, 'POSITIVE COUNT': 331.0, 'PERCENT POSITIVE': 0.7947751338631834}
# {'_id': ObjectId('65b87e57846c55748df46556'), '': 153, 'REGION': 'Idaho', 'MONTH': 'October', 'PATIENT COUNT': 39428.0, 'POSITIVE COUNT': 339.0, 'PERCENT POSITIVE': 0.8597950694937607}
# {'_id': ObjectId('65b87e57846c55748df46557'), '': 154, 'REGION': 'Idaho', 'MONTH': 'November', 'PATIENT COUNT': 51287.0, 'POSITIVE COUNT': 745.0, 'PERCENT POSITIVE': 1.4526098231520659}
# {'_id': ObjectId('65b87e57846c55748df46558'), '': 155, 'REGION': 'Idaho', 'MONTH': 'December', 'PATIENT COUNT': 48228.0, 'POSITIVE COUNT': 2192.0, 'PERCENT POSITIVE': 4.545077548312184}
# {'_id': ObjectId('65b87e57846c55748df46559'), '': 156, 'REGION': 'Illinois', 'MONTH': 'January', 'PATIENT COUNT': 278852.0, 'POSITIVE COUNT': 6030.0, 'PERCENT POSITIVE': 2.1624374220016356}
# {'_id': ObjectId('65b87e57846c55748df4655a'), '': 157, 'REGION': 'Illinois', 'MONTH': 'February', 'PATIENT COUNT': 288872.0, 'POSITIVE COUNT': 6332.0, 'PERCENT POSITIVE': 2.191974300036002}
# {'_id': ObjectId('65b87e57846c55748df4655b'), '': 158, 'REGION': 'Illinois', 'MONTH': 'March', 'PATIENT COUNT': 368871.0, 'POSITIVE COUNT': 8279.0, 'PERCENT POSITIVE': 2.244416069574458}
# {'_id': ObjectId('65b87e57846c55748df4655c'), '': 159, 'REGION': 'Illinois', 'MONTH': 'April', 'PATIENT COUNT': 286857.0, 'POSITIVE COUNT': 4361.0, 'PERCENT POSITIVE': 1.5202696814092038}
# {'_id': ObjectId('65b87e57846c55748df4655d'), '': 160, 'REGION': 'Illinois', 'MONTH': 'May', 'PATIENT COUNT': 234019.0, 'POSITIVE COUNT': 2792.0, 'PERCENT POSITIVE': 1.1930655203209997}
# {'_id': ObjectId('65b87e57846c55748df4655e'), '': 161, 'REGION': 'Illinois', 'MONTH': 'June', 'PATIENT COUNT': 348080.0, 'POSITIVE COUNT': 2806.0, 'PERCENT POSITIVE': 0.8061365203401517}
# {'_id': ObjectId('65b87e57846c55748df4655f'), '': 162, 'REGION': 'Illinois', 'MONTH': 'July', 'PATIENT COUNT': 277234.0, 'POSITIVE COUNT': 1662.0, 'PERCENT POSITIVE': 0.5994935686099108}
# {'_id': ObjectId('65b87e57846c55748df46560'), '': 163, 'REGION': 'Illinois', 'MONTH': 'August', 'PATIENT COUNT': 363565.0, 'POSITIVE COUNT': 3516.0, 'PERCENT POSITIVE': 0.9670897913715566}
# {'_id': ObjectId('65b87e57846c55748df46561'), '': 164, 'REGION': 'Illinois', 'MONTH': 'September', 'PATIENT COUNT': 297956.0, 'POSITIVE COUNT': 4195.0, 'PERCENT POSITIVE': 1.407926002497013}
# {'_id': ObjectId('65b87e57846c55748df46562'), '': 165, 'REGION': 'Illinois', 'MONTH': 'October', 'PATIENT COUNT': 295855.0, 'POSITIVE COUNT': 4706.0, 'PERCENT POSITIVE': 1.5906440655050615}
# {'_id': ObjectId('65b87e57846c55748df46563'), '': 166, 'REGION': 'Illinois', 'MONTH': 'November', 'PATIENT COUNT': 368551.0, 'POSITIVE COUNT': 9713.0, 'PERCENT POSITIVE': 2.635456151251794}
# {'_id': ObjectId('65b87e57846c55748df46564'), '': 167, 'REGION': 'Illinois', 'MONTH': 'December', 'PATIENT COUNT': 298110.0, 'POSITIVE COUNT': 10673.0, 'PERCENT POSITIVE': 3.5802220656804535}
# {'_id': ObjectId('65b87e57846c55748df46565'), '': 168, 'REGION': 'Indiana', 'MONTH': 'January', 'PATIENT COUNT': 199192.0, 'POSITIVE COUNT': 4162.0, 'PERCENT POSITIVE': 2.089441343025824}
# {'_id': ObjectId('65b87e57846c55748df46566'), '': 169, 'REGION': 'Indiana', 'MONTH': 'February', 'PATIENT COUNT': 219434.0, 'POSITIVE COUNT': 3819.0, 'PERCENT POSITIVE': 1.7403866310599085}
# {'_id': ObjectId('65b87e57846c55748df46567'), '': 170, 'REGION': 'Indiana', 'MONTH': 'March', 'PATIENT COUNT': 277080.0, 'POSITIVE COUNT': 4756.0, 'PERCENT POSITIVE': 1.7164717771040856}
# {'_id': ObjectId('65b87e57846c55748df46568'), '': 171, 'REGION': 'Indiana', 'MONTH': 'April', 'PATIENT COUNT': 223657.0, 'POSITIVE COUNT': 2943.0, 'PERCENT POSITIVE': 1.3158541874388014}
# {'_id': ObjectId('65b87e57846c55748df46569'), '': 172, 'REGION': 'Indiana', 'MONTH': 'May', 'PATIENT COUNT': 218335.0, 'POSITIVE COUNT': 2584.0, 'PERCENT POSITIVE': 1.1835024160120915}
# {'_id': ObjectId('65b87e57846c55748df4656a'), '': 173, 'REGION': 'Indiana', 'MONTH': 'June', 'PATIENT COUNT': 272120.0, 'POSITIVE COUNT': 2191.0, 'PERCENT POSITIVE': 0.8051594884609732}
# {'_id': ObjectId('65b87e57846c55748df4656b'), '': 174, 'REGION': 'Indiana', 'MONTH': 'July', 'PATIENT COUNT': 216640.0, 'POSITIVE COUNT': 1322.0, 'PERCENT POSITIVE': 0.6102289512555392}
# {'_id': ObjectId('65b87e57846c55748df4656c'), '': 175, 'REGION': 'Indiana', 'MONTH': 'August', 'PATIENT COUNT': 282094.0, 'POSITIVE COUNT': 2813.0, 'PERCENT POSITIVE': 0.997185335384659}
# {'_id': ObjectId('65b87e57846c55748df4656d'), '': 176, 'REGION': 'Indiana', 'MONTH': 'September', 'PATIENT COUNT': 233417.0, 'POSITIVE COUNT': 3281.0, 'PERCENT POSITIVE': 1.4056388352176576}
# {'_id': ObjectId('65b87e57846c55748df4656e'), '': 177, 'REGION': 'Indiana', 'MONTH': 'October', 'PATIENT COUNT': 278410.0, 'POSITIVE COUNT': 4893.0, 'PERCENT POSITIVE': 1.75747997557559}
# {'_id': ObjectId('65b87e57846c55748df4656f'), '': 178, 'REGION': 'Indiana', 'MONTH': 'November', 'PATIENT COUNT': 374646.0, 'POSITIVE COUNT': 9128.0, 'PERCENT POSITIVE': 2.436433326393449}
# {'_id': ObjectId('65b87e57846c55748df46570'), '': 179, 'REGION': 'Indiana', 'MONTH': 'December', 'PATIENT COUNT': 284122.0, 'POSITIVE COUNT': 11123.0, 'PERCENT POSITIVE': 3.914867556894573}
# {'_id': ObjectId('65b87e57846c55748df46571'), '': 180, 'REGION': 'Iowa', 'MONTH': 'January', 'PATIENT COUNT': 26332.0, 'POSITIVE COUNT': 1336.0, 'PERCENT POSITIVE': 5.073674616436275}
# {'_id': ObjectId('65b87e57846c55748df46572'), '': 181, 'REGION': 'Iowa', 'MONTH': 'February', 'PATIENT COUNT': 27801.0, 'POSITIVE COUNT': 444.0, 'PERCENT POSITIVE': 1.597064853782238}
# {'_id': ObjectId('65b87e57846c55748df46573'), '': 182, 'REGION': 'Iowa', 'MONTH': 'March', 'PATIENT COUNT': 33378.0, 'POSITIVE COUNT': 499.0, 'PERCENT POSITIVE': 1.4949967044160823}
# {'_id': ObjectId('65b87e57846c55748df46574'), '': 183, 'REGION': 'Iowa', 'MONTH': 'April', 'PATIENT COUNT': 24644.0, 'POSITIVE COUNT': 267.0, 'PERCENT POSITIVE': 1.083428014932641}
# {'_id': ObjectId('65b87e57846c55748df46575'), '': 184, 'REGION': 'Iowa', 'MONTH': 'May', 'PATIENT COUNT': 20231.0, 'POSITIVE COUNT': 179.0, 'PERCENT POSITIVE': 0.8847807819682665}
# {'_id': ObjectId('65b87e57846c55748df46576'), '': 185, 'REGION': 'Iowa', 'MONTH': 'June', 'PATIENT COUNT': 19846.0, 'POSITIVE COUNT': 137.0, 'PERCENT POSITIVE': 0.6903154288017737}
# {'_id': ObjectId('65b87e57846c55748df46577'), '': 186, 'REGION': 'Iowa', 'MONTH': 'July', 'PATIENT COUNT': 15305.0, 'POSITIVE COUNT': 94.0, 'PERCENT POSITIVE': 0.6141783730806926}
# {'_id': ObjectId('65b87e57846c55748df46578'), '': 187, 'REGION': 'Iowa', 'MONTH': 'August', 'PATIENT COUNT': 26328.0, 'POSITIVE COUNT': 230.0, 'PERCENT POSITIVE': 0.8735946520814343}
# {'_id': ObjectId('65b87e57846c55748df46579'), '': 188, 'REGION': 'Iowa', 'MONTH': 'September', 'PATIENT COUNT': 26824.0, 'POSITIVE COUNT': 196.0, 'PERCENT POSITIVE': 0.7306889352818371}
# {'_id': ObjectId('65b87e57846c55748df4657a'), '': 189, 'REGION': 'Iowa', 'MONTH': 'October', 'PATIENT COUNT': 28451.0, 'POSITIVE COUNT': 247.0, 'PERCENT POSITIVE': 0.8681592914133072}
# {'_id': ObjectId('65b87e57846c55748df4657b'), '': 190, 'REGION': 'Iowa', 'MONTH': 'November', 'PATIENT COUNT': 36429.0, 'POSITIVE COUNT': 809.0, 'PERCENT POSITIVE': 2.2207581871585824}
# {'_id': ObjectId('65b87e57846c55748df4657c'), '': 191, 'REGION': 'Iowa', 'MONTH': 'December', 'PATIENT COUNT': 29981.0, 'POSITIVE COUNT': 1964.0, 'PERCENT POSITIVE': 6.550815516493779}
# {'_id': ObjectId('65b87e57846c55748df4657d'), '': 192, 'REGION': 'Kansas', 'MONTH': 'January', 'PATIENT COUNT': 71570.0, 'POSITIVE COUNT': 1450.0, 'PERCENT POSITIVE': 2.0259885426854827}
# {'_id': ObjectId('65b87e57846c55748df4657e'), '': 193, 'REGION': 'Kansas', 'MONTH': 'February', 'PATIENT COUNT': 72673.0, 'POSITIVE COUNT': 1094.0, 'PERCENT POSITIVE': 1.505373384888473}
# {'_id': ObjectId('65b87e57846c55748df4657f'), '': 194, 'REGION': 'Kansas', 'MONTH': 'March', 'PATIENT COUNT': 87610.0, 'POSITIVE COUNT': 1091.0, 'PERCENT POSITIVE': 1.2452916333751856}
# {'_id': ObjectId('65b87e57846c55748df46580'), '': 195, 'REGION': 'Kansas', 'MONTH': 'April', 'PATIENT COUNT': 69139.0, 'POSITIVE COUNT': 654.0, 'PERCENT POSITIVE': 0.9459205368894545}
# {'_id': ObjectId('65b87e57846c55748df46581'), '': 196, 'REGION': 'Kansas', 'MONTH': 'May', 'PATIENT COUNT': 66398.0, 'POSITIVE COUNT': 516.0, 'PERCENT POSITIVE': 0.7771318413205217}
# {'_id': ObjectId('65b87e57846c55748df46582'), '': 197, 'REGION': 'Kansas', 'MONTH': 'June', 'PATIENT COUNT': 76415.0, 'POSITIVE COUNT': 370.0, 'PERCENT POSITIVE': 0.484198128639665}
# {'_id': ObjectId('65b87e57846c55748df46583'), '': 198, 'REGION': 'Kansas', 'MONTH': 'July', 'PATIENT COUNT': 60465.0, 'POSITIVE COUNT': 238.0, 'PERCENT POSITIVE': 0.39361614156950303}
# {'_id': ObjectId('65b87e57846c55748df46584'), '': 199, 'REGION': 'Kansas', 'MONTH': 'August', 'PATIENT COUNT': 79833.0, 'POSITIVE COUNT': 428.0, 'PERCENT POSITIVE': 0.5361191487229592}
# {'_id': ObjectId('65b87e57846c55748df46585'), '': 200, 'REGION': 'Kansas', 'MONTH': 'September', 'PATIENT COUNT': 70955.0, 'POSITIVE COUNT': 461.0, 'PERCENT POSITIVE': 0.6497075611302938}
# {'_id': ObjectId('65b87e57846c55748df46586'), '': 201, 'REGION': 'Kansas', 'MONTH': 'October', 'PATIENT COUNT': 78733.0, 'POSITIVE COUNT': 742.0, 'PERCENT POSITIVE': 0.9424256664930842}
# {'_id': ObjectId('65b87e57846c55748df46587'), '': 202, 'REGION': 'Kansas', 'MONTH': 'November', 'PATIENT COUNT': 95506.0, 'POSITIVE COUNT': 1482.0, 'PERCENT POSITIVE': 1.55173496953071}
# {'_id': ObjectId('65b87e57846c55748df46588'), '': 203, 'REGION': 'Kansas', 'MONTH': 'December', 'PATIENT COUNT': 75469.0, 'POSITIVE COUNT': 2293.0, 'PERCENT POSITIVE': 3.0383336204269304}
# {'_id': ObjectId('65b87e57846c55748df46589'), '': 204, 'REGION': 'Kentucky', 'MONTH': 'January', 'PATIENT COUNT': 140114.0, 'POSITIVE COUNT': 3597.0, 'PERCENT POSITIVE': 2.5671952838403014}
# {'_id': ObjectId('65b87e57846c55748df4658a'), '': 205, 'REGION': 'Kentucky', 'MONTH': 'February', 'PATIENT COUNT': 142444.0, 'POSITIVE COUNT': 3181.0, 'PERCENT POSITIVE': 2.2331582937856282}
# {'_id': ObjectId('65b87e57846c55748df4658b'), '': 206, 'REGION': 'Kentucky', 'MONTH': 'March', 'PATIENT COUNT': 181549.0, 'POSITIVE COUNT': 3532.0, 'PERCENT POSITIVE': 1.9454802835598102}
# {'_id': ObjectId('65b87e57846c55748df4658c'), '': 207, 'REGION': 'Kentucky', 'MONTH': 'April', 'PATIENT COUNT': 141196.0, 'POSITIVE COUNT': 2074.0, 'PERCENT POSITIVE': 1.4688801382475425}
# {'_id': ObjectId('65b87e57846c55748df4658d'), '': 208, 'REGION': 'Kentucky', 'MONTH': 'May', 'PATIENT COUNT': 127415.0, 'POSITIVE COUNT': 1609.0, 'PERCENT POSITIVE': 1.2628026527488914}
# {'_id': ObjectId('65b87e57846c55748df4658e'), '': 209, 'REGION': 'Kentucky', 'MONTH': 'June', 'PATIENT COUNT': 141693.0, 'POSITIVE COUNT': 977.0, 'PERCENT POSITIVE': 0.6895188894299649}
# {'_id': ObjectId('65b87e57846c55748df4658f'), '': 210, 'REGION': 'Kentucky', 'MONTH': 'July', 'PATIENT COUNT': 128296.0, 'POSITIVE COUNT': 763.0, 'PERCENT POSITIVE': 0.5947184635530336}
# {'_id': ObjectId('65b87e57846c55748df46590'), '': 211, 'REGION': 'Kentucky', 'MONTH': 'August', 'PATIENT COUNT': 167597.0, 'POSITIVE COUNT': 1846.0, 'PERCENT POSITIVE': 1.1014516966294146}
# {'_id': ObjectId('65b87e57846c55748df46591'), '': 212, 'REGION': 'Kentucky', 'MONTH': 'September', 'PATIENT COUNT': 142542.0, 'POSITIVE COUNT': 2264.0, 'PERCENT POSITIVE': 1.5883037981787824}
# {'_id': ObjectId('65b87e57846c55748df46592'), '': 213, 'REGION': 'Kentucky', 'MONTH': 'October', 'PATIENT COUNT': 151959.0, 'POSITIVE COUNT': 2240.0, 'PERCENT POSITIVE': 1.4740818247027159}
# {'_id': ObjectId('65b87e57846c55748df46593'), '': 214, 'REGION': 'Kentucky', 'MONTH': 'November', 'PATIENT COUNT': 198136.0, 'POSITIVE COUNT': 5102.0, 'PERCENT POSITIVE': 2.5749989905923205}
# {'_id': ObjectId('65b87e57846c55748df46594'), '': 215, 'REGION': 'Kentucky', 'MONTH': 'December', 'PATIENT COUNT': 164454.0, 'POSITIVE COUNT': 7655.0, 'PERCENT POSITIVE': 4.654797086115266}
# {'_id': ObjectId('65b87e57846c55748df46595'), '': 216, 'REGION': 'Louisiana', 'MONTH': 'January', 'PATIENT COUNT': 172171.0, 'POSITIVE COUNT': 3962.0, 'PERCENT POSITIVE': 2.3012005506153765}
# {'_id': ObjectId('65b87e57846c55748df46596'), '': 217, 'REGION': 'Louisiana', 'MONTH': 'February', 'PATIENT COUNT': 169091.0, 'POSITIVE COUNT': 2918.0, 'PERCENT POSITIVE': 1.7256979969365607}
# {'_id': ObjectId('65b87e57846c55748df46597'), '': 218, 'REGION': 'Louisiana', 'MONTH': 'March', 'PATIENT COUNT': 214162.0, 'POSITIVE COUNT': 2939.0, 'PERCENT POSITIVE': 1.372325622659482}
# {'_id': ObjectId('65b87e57846c55748df46598'), '': 219, 'REGION': 'Louisiana', 'MONTH': 'April', 'PATIENT COUNT': 168534.0, 'POSITIVE COUNT': 2200.0, 'PERCENT POSITIVE': 1.3053745831701615}
# {'_id': ObjectId('65b87e57846c55748df46599'), '': 220, 'REGION': 'Louisiana', 'MONTH': 'May', 'PATIENT COUNT': 172104.0, 'POSITIVE COUNT': 2220.0, 'PERCENT POSITIVE': 1.289917724166783}
# {'_id': ObjectId('65b87e57846c55748df4659a'), '': 221, 'REGION': 'Louisiana', 'MONTH': 'June', 'PATIENT COUNT': 210712.0, 'POSITIVE COUNT': 1841.0, 'PERCENT POSITIVE': 0.8737043927256161}
# {'_id': ObjectId('65b87e57846c55748df4659b'), '': 222, 'REGION': 'Louisiana', 'MONTH': 'July', 'PATIENT COUNT': 166767.0, 'POSITIVE COUNT': 1369.0, 'PERCENT POSITIVE': 0.8209058146995509}
# {'_id': ObjectId('65b87e57846c55748df4659c'), '': 223, 'REGION': 'Louisiana', 'MONTH': 'August', 'PATIENT COUNT': 219361.0, 'POSITIVE COUNT': 3233.0, 'PERCENT POSITIVE': 1.4738262498803343}
# {'_id': ObjectId('65b87e57846c55748df4659d'), '': 224, 'REGION': 'Louisiana', 'MONTH': 'September', 'PATIENT COUNT': 179287.0, 'POSITIVE COUNT': 3267.0, 'PERCENT POSITIVE': 1.822218007998349}
# {'_id': ObjectId('65b87e57846c55748df4659e'), '': 225, 'REGION': 'Louisiana', 'MONTH': 'October', 'PATIENT COUNT': 174050.0, 'POSITIVE COUNT': 4827.0, 'PERCENT POSITIVE': 2.773340993967251}
# {'_id': ObjectId('65b87e57846c55748df4659f'), '': 226, 'REGION': 'Louisiana', 'MONTH': 'November', 'PATIENT COUNT': 224104.0, 'POSITIVE COUNT': 14720.0, 'PERCENT POSITIVE': 6.568378966908221}
# {'_id': ObjectId('65b87e57846c55748df465a0'), '': 227, 'REGION': 'Louisiana', 'MONTH': 'December', 'PATIENT COUNT': 189117.0, 'POSITIVE COUNT': 22967.0, 'PERCENT POSITIVE': 12.144333930847042}
# {'_id': ObjectId('65b87e57846c55748df465a1'), '': 228, 'REGION': 'Maine', 'MONTH': 'January', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465a2'), '': 229, 'REGION': 'Maine', 'MONTH': 'February', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465a3'), '': 230, 'REGION': 'Maine', 'MONTH': 'March', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465a4'), '': 231, 'REGION': 'Maine', 'MONTH': 'April', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465a5'), '': 232, 'REGION': 'Maine', 'MONTH': 'May', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465a6'), '': 233, 'REGION': 'Maine', 'MONTH': 'June', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465a7'), '': 234, 'REGION': 'Maine', 'MONTH': 'July', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465a8'), '': 235, 'REGION': 'Maine', 'MONTH': 'August', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465a9'), '': 236, 'REGION': 'Maine', 'MONTH': 'September', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df465aa'), '': 237, 'REGION': 'Maine', 'MONTH': 'October', 'PATIENT COUNT': 65396.0, 'POSITIVE COUNT': 538.0, 'PERCENT POSITIVE': 0.8226802862560402}
# {'_id': ObjectId('65b87e57846c55748df465ab'), '': 238, 'REGION': 'Maine', 'MONTH': 'November', 'PATIENT COUNT': 77225.0, 'POSITIVE COUNT': 1002.0, 'PERCENT POSITIVE': 1.2975072839106507}
# {'_id': ObjectId('65b87e57846c55748df465ac'), '': 239, 'REGION': 'Maine', 'MONTH': 'December', 'PATIENT COUNT': 64620.0, 'POSITIVE COUNT': 2015.0, 'PERCENT POSITIVE': 3.1182296502630766}
# {'_id': ObjectId('65b87e57846c55748df465ad'), '': 240, 'REGION': 'Maryland', 'MONTH': 'January', 'PATIENT COUNT': 171039.0, 'POSITIVE COUNT': 4437.0, 'PERCENT POSITIVE': 2.5941451949555367}
# {'_id': ObjectId('65b87e57846c55748df465ae'), '': 241, 'REGION': 'Maryland', 'MONTH': 'February', 'PATIENT COUNT': 178422.0, 'POSITIVE COUNT': 4026.0, 'PERCENT POSITIVE': 2.2564481958502873}
# {'_id': ObjectId('65b87e57846c55748df465af'), '': 242, 'REGION': 'Maryland', 'MONTH': 'March', 'PATIENT COUNT': 229330.0, 'POSITIVE COUNT': 5003.0, 'PERCENT POSITIVE': 2.181572406575677}
# {'_id': ObjectId('65b87e57846c55748df465b0'), '': 243, 'REGION': 'Maryland', 'MONTH': 'April', 'PATIENT COUNT': 180721.0, 'POSITIVE COUNT': 3014.0, 'PERCENT POSITIVE': 1.6677641225978166}
# {'_id': ObjectId('65b87e57846c55748df465b1'), '': 244, 'REGION': 'Maryland', 'MONTH': 'May', 'PATIENT COUNT': 184294.0, 'POSITIVE COUNT': 3128.0, 'PERCENT POSITIVE': 1.6972880289103283}
# {'_id': ObjectId('65b87e57846c55748df465b2'), '': 245, 'REGION': 'Maryland', 'MONTH': 'June', 'PATIENT COUNT': 222348.0, 'POSITIVE COUNT': 3217.0, 'PERCENT POSITIVE': 1.4468310936010218}
# {'_id': ObjectId('65b87e57846c55748df465b3'), '': 246, 'REGION': 'Maryland', 'MONTH': 'July', 'PATIENT COUNT': 177078.0, 'POSITIVE COUNT': 1815.0, 'PERCENT POSITIVE': 1.0249720462169214}
# {'_id': ObjectId('65b87e57846c55748df465b4'), '': 247, 'REGION': 'Maryland', 'MONTH': 'August', 'PATIENT COUNT': 222405.0, 'POSITIVE COUNT': 2604.0, 'PERCENT POSITIVE': 1.170836986578539}
# {'_id': ObjectId('65b87e57846c55748df465b5'), '': 248, 'REGION': 'Maryland', 'MONTH': 'September', 'PATIENT COUNT': 184778.0, 'POSITIVE COUNT': 3199.0, 'PERCENT POSITIVE': 1.7312667092402776}
# {'_id': ObjectId('65b87e57846c55748df465b6'), '': 249, 'REGION': 'Maryland', 'MONTH': 'October', 'PATIENT COUNT': 195709.0, 'POSITIVE COUNT': 4883.0, 'PERCENT POSITIVE': 2.495030887695507}
# {'_id': ObjectId('65b87e57846c55748df465b7'), '': 250, 'REGION': 'Maryland', 'MONTH': 'November', 'PATIENT COUNT': 240537.0, 'POSITIVE COUNT': 7547.0, 'PERCENT POSITIVE': 3.137563036040193}
# {'_id': ObjectId('65b87e57846c55748df465b8'), '': 251, 'REGION': 'Maryland', 'MONTH': 'December', 'PATIENT COUNT': 198346.0, 'POSITIVE COUNT': 9784.0, 'PERCENT POSITIVE': 4.9327942081009954}
# {'_id': ObjectId('65b87e57846c55748df465b9'), '': 252, 'REGION': 'Massachusetts', 'MONTH': 'January', 'PATIENT COUNT': 318070.0, 'POSITIVE COUNT': 9753.0, 'PERCENT POSITIVE': 3.066306159021599}
# {'_id': ObjectId('65b87e57846c55748df465ba'), '': 253, 'REGION': 'Massachusetts', 'MONTH': 'February', 'PATIENT COUNT': 314821.0, 'POSITIVE COUNT': 5432.0, 'PERCENT POSITIVE': 1.7254249240044341}
# {'_id': ObjectId('65b87e57846c55748df465bb'), '': 254, 'REGION': 'Massachusetts', 'MONTH': 'March', 'PATIENT COUNT': 401807.0, 'POSITIVE COUNT': 6214.0, 'PERCENT POSITIVE': 1.5465136247004159}
# {'_id': ObjectId('65b87e57846c55748df465bc'), '': 255, 'REGION': 'Massachusetts', 'MONTH': 'April', 'PATIENT COUNT': 323475.0, 'POSITIVE COUNT': 4552.0, 'PERCENT POSITIVE': 1.407218486745498}
# {'_id': ObjectId('65b87e57846c55748df465bd'), '': 256, 'REGION': 'Massachusetts', 'MONTH': 'May', 'PATIENT COUNT': 337713.0, 'POSITIVE COUNT': 4297.0, 'PERCENT POSITIVE': 1.2723821706597023}
# {'_id': ObjectId('65b87e57846c55748df465be'), '': 257, 'REGION': 'Massachusetts', 'MONTH': 'June', 'PATIENT COUNT': 413480.0, 'POSITIVE COUNT': 4389.0, 'PERCENT POSITIVE': 1.0614781851601045}
# {'_id': ObjectId('65b87e57846c55748df465bf'), '': 258, 'REGION': 'Massachusetts', 'MONTH': 'July', 'PATIENT COUNT': 321428.0, 'POSITIVE COUNT': 2479.0, 'PERCENT POSITIVE': 0.7712458155481166}
# {'_id': ObjectId('65b87e57846c55748df465c0'), '': 259, 'REGION': 'Massachusetts', 'MONTH': 'August', 'PATIENT COUNT': 402726.0, 'POSITIVE COUNT': 3241.0, 'PERCENT POSITIVE': 0.8047655229610207}
# {'_id': ObjectId('65b87e57846c55748df465c1'), '': 260, 'REGION': 'Massachusetts', 'MONTH': 'September', 'PATIENT COUNT': 329542.0, 'POSITIVE COUNT': 3682.0, 'PERCENT POSITIVE': 1.1173082641969765}
# {'_id': ObjectId('65b87e57846c55748df465c2'), '': 261, 'REGION': 'Massachusetts', 'MONTH': 'October', 'PATIENT COUNT': 361832.0, 'POSITIVE COUNT': 4995.0, 'PERCENT POSITIVE': 1.380474916535851}
# {'_id': ObjectId('65b87e57846c55748df465c3'), '': 262, 'REGION': 'Massachusetts', 'MONTH': 'November', 'PATIENT COUNT': 440702.0, 'POSITIVE COUNT': 9783.0, 'PERCENT POSITIVE': 2.2198673933860067}
# {'_id': ObjectId('65b87e57846c55748df465c4'), '': 263, 'REGION': 'Massachusetts', 'MONTH': 'December', 'PATIENT COUNT': 362464.0, 'POSITIVE COUNT': 17777.0, 'PERCENT POSITIVE': 4.904487066301757}
# {'_id': ObjectId('65b87e57846c55748df465c5'), '': 264, 'REGION': 'Michigan', 'MONTH': 'January', 'PATIENT COUNT': 320568.0, 'POSITIVE COUNT': 4998.0, 'PERCENT POSITIVE': 1.559107584038332}
# {'_id': ObjectId('65b87e57846c55748df465c6'), '': 265, 'REGION': 'Michigan', 'MONTH': 'February', 'PATIENT COUNT': 326199.0, 'POSITIVE COUNT': 3769.0, 'PERCENT POSITIVE': 1.155429661035135}
# ...
# {'_id': ObjectId('65b87e57846c55748df466eb'), '': 558, 'REGION': 'Utah', 'MONTH': 'July', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df466ec'), '': 559, 'REGION': 'Utah', 'MONTH': 'August', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df466ed'), '': 560, 'REGION': 'Utah', 'MONTH': 'September', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df466ee'), '': 561, 'REGION': 'Utah', 'MONTH': 'October', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df466ef'), '': 562, 'REGION': 'Utah', 'MONTH': 'November', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df466f0'), '': 563, 'REGION': 'Utah', 'MONTH': 'December', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df466f1'), '': 564, 'REGION': 'Vermont', 'MONTH': 'January', 'PATIENT COUNT': 25680.0, 'POSITIVE COUNT': 475.0, 'PERCENT POSITIVE': 1.849688473520249}
# {'_id': ObjectId('65b87e57846c55748df466f2'), '': 565, 'REGION': 'Vermont', 'MONTH': 'February', 'PATIENT COUNT': 24574.0, 'POSITIVE COUNT': 207.0, 'PERCENT POSITIVE': 0.8423537071701799}
# {'_id': ObjectId('65b87e57846c55748df466f3'), '': 566, 'REGION': 'Vermont', 'MONTH': 'March', 'PATIENT COUNT': 29765.0, 'POSITIVE COUNT': 222.0, 'PERCENT POSITIVE': 0.7458424323870317}
# {'_id': ObjectId('65b87e57846c55748df466f4'), '': 567, 'REGION': 'Vermont', 'MONTH': 'April', 'PATIENT COUNT': 23547.0, 'POSITIVE COUNT': 127.0, 'PERCENT POSITIVE': 0.5393468382384168}
# {'_id': ObjectId('65b87e57846c55748df466f5'), '': 568, 'REGION': 'Vermont', 'MONTH': 'May', 'PATIENT COUNT': 23416.0, 'POSITIVE COUNT': 104.0, 'PERCENT POSITIVE': 0.4441407584557568}
# {'_id': ObjectId('65b87e57846c55748df466f6'), '': 569, 'REGION': 'Vermont', 'MONTH': 'June', 'PATIENT COUNT': 29820.0, 'POSITIVE COUNT': 112.0, 'PERCENT POSITIVE': 0.3755868544600939}
# {'_id': ObjectId('65b87e57846c55748df466f7'), '': 570, 'REGION': 'Vermont', 'MONTH': 'July', 'PATIENT COUNT': 21487.0, 'POSITIVE COUNT': 86.0, 'PERCENT POSITIVE': 0.40024200679480615}
# {'_id': ObjectId('65b87e57846c55748df466f8'), '': 571, 'REGION': 'Vermont', 'MONTH': 'August', 'PATIENT COUNT': 26859.0, 'POSITIVE COUNT': 84.0, 'PERCENT POSITIVE': 0.3127443315089914}
# {'_id': ObjectId('65b87e57846c55748df466f9'), '': 572, 'REGION': 'Vermont', 'MONTH': 'September', 'PATIENT COUNT': 21984.0, 'POSITIVE COUNT': 109.0, 'PERCENT POSITIVE': 0.49581513828238716}
# {'_id': ObjectId('65b87e57846c55748df466fa'), '': 573, 'REGION': 'Vermont', 'MONTH': 'October', 'PATIENT COUNT': 26576.0, 'POSITIVE COUNT': 190.0, 'PERCENT POSITIVE': 0.7149307645996388}
# {'_id': ObjectId('65b87e57846c55748df466fb'), '': 574, 'REGION': 'Vermont', 'MONTH': 'November', 'PATIENT COUNT': 31593.0, 'POSITIVE COUNT': 399.0, 'PERCENT POSITIVE': 1.262937992593296}
# {'_id': ObjectId('65b87e57846c55748df466fc'), '': 575, 'REGION': 'Vermont', 'MONTH': 'December', 'PATIENT COUNT': 23794.0, 'POSITIVE COUNT': 509.0, 'PERCENT POSITIVE': 2.139194754980247}
# {'_id': ObjectId('65b87e57846c55748df466fd'), '': 576, 'REGION': 'Virgin Islands', 'MONTH': 'January', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df466fe'), '': 577, 'REGION': 'Virgin Islands', 'MONTH': 'February', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df466ff'), '': 578, 'REGION': 'Virgin Islands', 'MONTH': 'March', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46700'), '': 579, 'REGION': 'Virgin Islands', 'MONTH': 'April', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46701'), '': 580, 'REGION': 'Virgin Islands', 'MONTH': 'May', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46702'), '': 581, 'REGION': 'Virgin Islands', 'MONTH': 'June', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46703'), '': 582, 'REGION': 'Virgin Islands', 'MONTH': 'July', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46704'), '': 583, 'REGION': 'Virgin Islands', 'MONTH': 'August', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46705'), '': 584, 'REGION': 'Virgin Islands', 'MONTH': 'September', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46706'), '': 585, 'REGION': 'Virgin Islands', 'MONTH': 'October', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46707'), '': 586, 'REGION': 'Virgin Islands', 'MONTH': 'November', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46708'), '': 587, 'REGION': 'Virgin Islands', 'MONTH': 'December', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46709'), '': 588, 'REGION': 'Virginia', 'MONTH': 'January', 'PATIENT COUNT': 437983.0, 'POSITIVE COUNT': 15694.0, 'PERCENT POSITIVE': 3.583244098515239}
# {'_id': ObjectId('65b87e57846c55748df4670a'), '': 589, 'REGION': 'Virginia', 'MONTH': 'February', 'PATIENT COUNT': 443586.0, 'POSITIVE COUNT': 13751.0, 'PERCENT POSITIVE': 3.099962577718864}
# {'_id': ObjectId('65b87e57846c55748df4670b'), '': 590, 'REGION': 'Virginia', 'MONTH': 'March', 'PATIENT COUNT': 554442.0, 'POSITIVE COUNT': 15704.0, 'PERCENT POSITIVE': 2.832397257062055}
# {'_id': ObjectId('65b87e57846c55748df4670c'), '': 591, 'REGION': 'Virginia', 'MONTH': 'April', 'PATIENT COUNT': 433761.0, 'POSITIVE COUNT': 9767.0, 'PERCENT POSITIVE': 2.2517008214200906}
# {'_id': ObjectId('65b87e57846c55748df4670d'), '': 592, 'REGION': 'Virginia', 'MONTH': 'May', 'PATIENT COUNT': 448449.0, 'POSITIVE COUNT': 9854.0, 'PERCENT POSITIVE': 2.1973513153112174}
# {'_id': ObjectId('65b87e57846c55748df4670e'), '': 593, 'REGION': 'Virginia', 'MONTH': 'June', 'PATIENT COUNT': 547235.0, 'POSITIVE COUNT': 9339.0, 'PERCENT POSITIVE': 1.7065794402770291}
# {'_id': ObjectId('65b87e57846c55748df4670f'), '': 594, 'REGION': 'Virginia', 'MONTH': 'July', 'PATIENT COUNT': 433033.0, 'POSITIVE COUNT': 5324.0, 'PERCENT POSITIVE': 1.2294675001674238}
# {'_id': ObjectId('65b87e57846c55748df46710'), '': 595, 'REGION': 'Virginia', 'MONTH': 'August', 'PATIENT COUNT': 559276.0, 'POSITIVE COUNT': 8908.0, 'PERCENT POSITIVE': 1.59277351432924}
# {'_id': ObjectId('65b87e57846c55748df46711'), '': 596, 'REGION': 'Virginia', 'MONTH': 'September', 'PATIENT COUNT': 468702.0, 'POSITIVE COUNT': 11119.0, 'PERCENT POSITIVE': 2.372296256469996}
# {'_id': ObjectId('65b87e57846c55748df46712'), '': 597, 'REGION': 'Virginia', 'MONTH': 'October', 'PATIENT COUNT': 468741.0, 'POSITIVE COUNT': 13414.0, 'PERCENT POSITIVE': 2.8617082781322734}
# {'_id': ObjectId('65b87e57846c55748df46713'), '': 598, 'REGION': 'Virginia', 'MONTH': 'November', 'PATIENT COUNT': 533273.0, 'POSITIVE COUNT': 19468.0, 'PERCENT POSITIVE': 3.650662981249754}
# {'_id': ObjectId('65b87e57846c55748df46714'), '': 599, 'REGION': 'Virginia', 'MONTH': 'December', 'PATIENT COUNT': 511632.0, 'POSITIVE COUNT': 32272.0, 'PERCENT POSITIVE': 6.307658629640053}
# {'_id': ObjectId('65b87e57846c55748df46715'), '': 600, 'REGION': 'Washington', 'MONTH': 'January', 'PATIENT COUNT': 192642.0, 'POSITIVE COUNT': 3847.0, 'PERCENT POSITIVE': 1.9969684700117316}
# {'_id': ObjectId('65b87e57846c55748df46716'), '': 601, 'REGION': 'Washington', 'MONTH': 'February', 'PATIENT COUNT': 189182.0, 'POSITIVE COUNT': 2625.0, 'PERCENT POSITIVE': 1.387552727003626}
# {'_id': ObjectId('65b87e57846c55748df46717'), '': 602, 'REGION': 'Washington', 'MONTH': 'March', 'PATIENT COUNT': 256885.0, 'POSITIVE COUNT': 3575.0, 'PERCENT POSITIVE': 1.391673316853845}
# {'_id': ObjectId('65b87e57846c55748df46718'), '': 603, 'REGION': 'Washington', 'MONTH': 'April', 'PATIENT COUNT': 196565.0, 'POSITIVE COUNT': 2415.0, 'PERCENT POSITIVE': 1.228601226057538}
# {'_id': ObjectId('65b87e57846c55748df46719'), '': 604, 'REGION': 'Washington', 'MONTH': 'May', 'PATIENT COUNT': 196688.0, 'POSITIVE COUNT': 2080.0, 'PERCENT POSITIVE': 1.0575124054339868}
# {'_id': ObjectId('65b87e57846c55748df4671a'), '': 605, 'REGION': 'Washington', 'MONTH': 'June', 'PATIENT COUNT': 235770.0, 'POSITIVE COUNT': 2581.0, 'PERCENT POSITIVE': 1.094710947109471}
# {'_id': ObjectId('65b87e57846c55748df4671b'), '': 606, 'REGION': 'Washington', 'MONTH': 'July', 'PATIENT COUNT': 182476.0, 'POSITIVE COUNT': 1384.0, 'PERCENT POSITIVE': 0.7584559065301738}
# {'_id': ObjectId('65b87e57846c55748df4671c'), '': 607, 'REGION': 'Washington', 'MONTH': 'August', 'PATIENT COUNT': 231495.0, 'POSITIVE COUNT': 1984.0, 'PERCENT POSITIVE': 0.8570379489837793}
# {'_id': ObjectId('65b87e57846c55748df4671d'), '': 608, 'REGION': 'Washington', 'MONTH': 'September', 'PATIENT COUNT': 192276.0, 'POSITIVE COUNT': 2496.0, 'PERCENT POSITIVE': 1.2981339324720713}
# {'_id': ObjectId('65b87e57846c55748df4671e'), '': 609, 'REGION': 'Washington', 'MONTH': 'October', 'PATIENT COUNT': 313765.0, 'POSITIVE COUNT': 3207.0, 'PERCENT POSITIVE': 1.0221025289627588}
# {'_id': ObjectId('65b87e57846c55748df4671f'), '': 610, 'REGION': 'Washington', 'MONTH': 'November', 'PATIENT COUNT': 378861.0, 'POSITIVE COUNT': 6380.0, 'PERCENT POSITIVE': 1.6839949216203305}
# {'_id': ObjectId('65b87e57846c55748df46720'), '': 611, 'REGION': 'Washington', 'MONTH': 'December', 'PATIENT COUNT': 304513.0, 'POSITIVE COUNT': 10914.0, 'PERCENT POSITIVE': 3.5840834381454982}
# {'_id': ObjectId('65b87e57846c55748df46721'), '': 612, 'REGION': 'West Virginia', 'MONTH': 'January', 'PATIENT COUNT': 55218.0, 'POSITIVE COUNT': 1304.0, 'PERCENT POSITIVE': 2.361548770328516}
# {'_id': ObjectId('65b87e57846c55748df46722'), '': 613, 'REGION': 'West Virginia', 'MONTH': 'February', 'PATIENT COUNT': 57352.0, 'POSITIVE COUNT': 1140.0, 'PERCENT POSITIVE': 1.987724926768029}
# {'_id': ObjectId('65b87e57846c55748df46723'), '': 614, 'REGION': 'West Virginia', 'MONTH': 'March', 'PATIENT COUNT': 69809.0, 'POSITIVE COUNT': 1447.0, 'PERCENT POSITIVE': 2.07279863627899}
# {'_id': ObjectId('65b87e57846c55748df46724'), '': 615, 'REGION': 'West Virginia', 'MONTH': 'April', 'PATIENT COUNT': 46972.0, 'POSITIVE COUNT': 615.0, 'PERCENT POSITIVE': 1.3092906412330751}
# {'_id': ObjectId('65b87e57846c55748df46725'), '': 616, 'REGION': 'West Virginia', 'MONTH': 'May', 'PATIENT COUNT': 47109.0, 'POSITIVE COUNT': 1218.0, 'PERCENT POSITIVE': 2.5854932178564605}
# {'_id': ObjectId('65b87e57846c55748df46726'), '': 617, 'REGION': 'West Virginia', 'MONTH': 'June', 'PATIENT COUNT': 56003.0, 'POSITIVE COUNT': 330.0, 'PERCENT POSITIVE': 0.5892541470992625}
# {'_id': ObjectId('65b87e57846c55748df46727'), '': 618, 'REGION': 'West Virginia', 'MONTH': 'July', 'PATIENT COUNT': 42424.0, 'POSITIVE COUNT': 165.0, 'PERCENT POSITIVE': 0.3889307938902508}
# {'_id': ObjectId('65b87e57846c55748df46728'), '': 619, 'REGION': 'West Virginia', 'MONTH': 'August', 'PATIENT COUNT': 57028.0, 'POSITIVE COUNT': 400.0, 'PERCENT POSITIVE': 0.7014098337658694}
# {'_id': ObjectId('65b87e57846c55748df46729'), '': 620, 'REGION': 'West Virginia', 'MONTH': 'September', 'PATIENT COUNT': 49241.0, 'POSITIVE COUNT': 782.0, 'PERCENT POSITIVE': 1.5881074714160965}
# {'_id': ObjectId('65b87e57846c55748df4672a'), '': 621, 'REGION': 'West Virginia', 'MONTH': 'October', 'PATIENT COUNT': 61803.0, 'POSITIVE COUNT': 980.0, 'PERCENT POSITIVE': 1.5856835428700873}
# {'_id': ObjectId('65b87e57846c55748df4672b'), '': 622, 'REGION': 'West Virginia', 'MONTH': 'November', 'PATIENT COUNT': 78868.0, 'POSITIVE COUNT': 1552.0, 'PERCENT POSITIVE': 1.9678450068468836}
# {'_id': ObjectId('65b87e57846c55748df4672c'), '': 623, 'REGION': 'West Virginia', 'MONTH': 'December', 'PATIENT COUNT': 57491.0, 'POSITIVE COUNT': 1844.0, 'PERCENT POSITIVE': 3.2074585587309317}
# {'_id': ObjectId('65b87e57846c55748df4672d'), '': 624, 'REGION': 'Wisconsin', 'MONTH': 'January', 'PATIENT COUNT': 128304.0, 'POSITIVE COUNT': 5076.0, 'PERCENT POSITIVE': 3.9562289562289563}
# {'_id': ObjectId('65b87e57846c55748df4672e'), '': 625, 'REGION': 'Wisconsin', 'MONTH': 'February', 'PATIENT COUNT': 119290.0, 'POSITIVE COUNT': 1607.0, 'PERCENT POSITIVE': 1.3471372286025651}
# {'_id': ObjectId('65b87e57846c55748df4672f'), '': 626, 'REGION': 'Wisconsin', 'MONTH': 'March', 'PATIENT COUNT': 144238.0, 'POSITIVE COUNT': 1701.0, 'PERCENT POSITIVE': 1.1793008777159972}
# {'_id': ObjectId('65b87e57846c55748df46730'), '': 627, 'REGION': 'Wisconsin', 'MONTH': 'April', 'PATIENT COUNT': 107940.0, 'POSITIVE COUNT': 1178.0, 'PERCENT POSITIVE': 1.0913470446544375}
# {'_id': ObjectId('65b87e57846c55748df46731'), '': 628, 'REGION': 'Wisconsin', 'MONTH': 'May', 'PATIENT COUNT': 101504.0, 'POSITIVE COUNT': 940.0, 'PERCENT POSITIVE': 0.9260718789407313}
# {'_id': ObjectId('65b87e57846c55748df46732'), '': 629, 'REGION': 'Wisconsin', 'MONTH': 'June', 'PATIENT COUNT': 121537.0, 'POSITIVE COUNT': 911.0, 'PERCENT POSITIVE': 0.7495659757933798}
# {'_id': ObjectId('65b87e57846c55748df46733'), '': 630, 'REGION': 'Wisconsin', 'MONTH': 'July', 'PATIENT COUNT': 91051.0, 'POSITIVE COUNT': 452.0, 'PERCENT POSITIVE': 0.49642508044941847}
# {'_id': ObjectId('65b87e57846c55748df46734'), '': 631, 'REGION': 'Wisconsin', 'MONTH': 'August', 'PATIENT COUNT': 120425.0, 'POSITIVE COUNT': 684.0, 'PERCENT POSITIVE': 0.5679883745069545}
# {'_id': ObjectId('65b87e57846c55748df46735'), '': 632, 'REGION': 'Wisconsin', 'MONTH': 'September', 'PATIENT COUNT': 104416.0, 'POSITIVE COUNT': 1001.0, 'PERCENT POSITIVE': 0.9586653386454184}
# {'_id': ObjectId('65b87e57846c55748df46736'), '': 633, 'REGION': 'Wisconsin', 'MONTH': 'October', 'PATIENT COUNT': 141103.0, 'POSITIVE COUNT': 1599.0, 'PERCENT POSITIVE': 1.1332147438396065}
# {'_id': ObjectId('65b87e57846c55748df46737'), '': 634, 'REGION': 'Wisconsin', 'MONTH': 'November', 'PATIENT COUNT': 186903.0, 'POSITIVE COUNT': 4359.0, 'PERCENT POSITIVE': 2.3322258069693906}
# {'_id': ObjectId('65b87e57846c55748df46738'), '': 635, 'REGION': 'Wisconsin', 'MONTH': 'December', 'PATIENT COUNT': 178123.0, 'POSITIVE COUNT': 11452.0, 'PERCENT POSITIVE': 6.429265170696653}
# {'_id': ObjectId('65b87e57846c55748df46739'), '': 636, 'REGION': 'Wyoming', 'MONTH': 'January', 'PATIENT COUNT': 10630.0, 'POSITIVE COUNT': 283.0, 'PERCENT POSITIVE': 2.6622765757290687}
# {'_id': ObjectId('65b87e57846c55748df4673a'), '': 637, 'REGION': 'Wyoming', 'MONTH': 'February', 'PATIENT COUNT': 5389.0, 'POSITIVE COUNT': 126.0, 'PERCENT POSITIVE': 2.338096121729449}
# {'_id': ObjectId('65b87e57846c55748df4673b'), '': 638, 'REGION': 'Wyoming', 'MONTH': 'March', 'PATIENT COUNT': 5074.0, 'POSITIVE COUNT': 99.0, 'PERCENT POSITIVE': 1.951123374063855}
# {'_id': ObjectId('65b87e57846c55748df4673c'), '': 639, 'REGION': 'Wyoming', 'MONTH': 'April', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df4673d'), '': 640, 'REGION': 'Wyoming', 'MONTH': 'May', 'PATIENT COUNT': 2249.0, 'POSITIVE COUNT': 25.0, 'PERCENT POSITIVE': 1.1116051578479325}
# {'_id': ObjectId('65b87e57846c55748df4673e'), '': 641, 'REGION': 'Wyoming', 'MONTH': 'June', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df4673f'), '': 642, 'REGION': 'Wyoming', 'MONTH': 'July', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46740'), '': 643, 'REGION': 'Wyoming', 'MONTH': 'August', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46741'), '': 644, 'REGION': 'Wyoming', 'MONTH': 'September', 'PATIENT COUNT': 0.0, 'POSITIVE COUNT': 0.0}
# {'_id': ObjectId('65b87e57846c55748df46742'), '': 645, 'REGION': 'Wyoming', 'MONTH': 'October', 'PATIENT COUNT': 6410.0, 'POSITIVE COUNT': 310.0, 'PERCENT POSITIVE': 4.83619344773791}
# {'_id': ObjectId('65b87e57846c55748df46743'), '': 646, 'REGION': 'Wyoming', 'MONTH': 'November', 'PATIENT COUNT': 15182.0, 'POSITIVE COUNT': 808.0, 'PERCENT POSITIVE': 5.322091950994599}
# {'_id': ObjectId('65b87e57846c55748df46744'), '': 647, 'REGION': 'Wyoming', 'MONTH': 'December', 'PATIENT COUNT': 11329.0, 'POSITIVE COUNT': 928.0, 'PERCENT POSITIVE': 8.191367287492277}

# %%
for document in combined_national.find():
    print(document)
# Out:
# {'_id': ObjectId('65b87e26846c55748df464b0'), '': 0, 'MONTH': 'January', 'PATIENT COUNT': 9221974, 'POSITIVE COUNT': 296436, 'PERCENT POSITIVE': 3.2144527841869865}
# {'_id': ObjectId('65b87e26846c55748df464b1'), '': 1, 'MONTH': 'February', 'PATIENT COUNT': 9372154, 'POSITIVE COUNT': 243463, 'PERCENT POSITIVE': 2.5977272673923197}
# {'_id': ObjectId('65b87e26846c55748df464b2'), '': 2, 'MONTH': 'March', 'PATIENT COUNT': 11767869, 'POSITIVE COUNT': 277374, 'PERCENT POSITIVE': 2.3570452730226688}
# {'_id': ObjectId('65b87e26846c55748df464b3'), '': 3, 'MONTH': 'April', 'PATIENT COUNT': 9238102, 'POSITIVE COUNT': 186763, 'PERCENT POSITIVE': 2.021659860434535}
# {'_id': ObjectId('65b87e26846c55748df464b4'), '': 4, 'MONTH': 'May', 'PATIENT COUNT': 9125754, 'POSITIVE COUNT': 178301, 'PERCENT POSITIVE': 1.9538221170546564}
# {'_id': ObjectId('65b87e26846c55748df464b5'), '': 5, 'MONTH': 'June', 'PATIENT COUNT': 10951471, 'POSITIVE COUNT': 173815, 'PERCENT POSITIVE': 1.587138385336545}
# {'_id': ObjectId('65b87e26846c55748df464b6'), '': 6, 'MONTH': 'July', 'PATIENT COUNT': 8652484, 'POSITIVE COUNT': 106062, 'PERCENT POSITIVE': 1.225798279430508}
# {'_id': ObjectId('65b87e26846c55748df464b7'), '': 7, 'MONTH': 'August', 'PATIENT COUNT': 11175211, 'POSITIVE COUNT': 177025, 'PERCENT POSITIVE': 1.58408642127652}
# {'_id': ObjectId('65b87e26846c55748df464b8'), '': 8, 'MONTH': 'September', 'PATIENT COUNT': 9242530, 'POSITIVE COUNT': 189546, 'PERCENT POSITIVE': 2.0508021072152323}
# {'_id': ObjectId('65b87e26846c55748df464b9'), '': 9, 'MONTH': 'October', 'PATIENT COUNT': 10234657, 'POSITIVE COUNT': 247356, 'PERCENT POSITIVE': 2.416846993504521}
# {'_id': ObjectId('65b87e26846c55748df464ba'), '': 10, 'MONTH': 'November', 'PATIENT COUNT': 12885195, 'POSITIVE COUNT': 460417, 'PERCENT POSITIVE': 3.573224929851663}
# {'_id': ObjectId('65b87e26846c55748df464bb'), '': 11, 'MONTH': 'December', 'PATIENT COUNT': 10727985, 'POSITIVE COUNT': 658180, 'PERCENT POSITIVE': 6.13516890636965}

# %% [markdown]
# Setting up a Flask API with JSON output:

# %% [markdown]
# Set up a Flask application.

# %%
from flask import Flask, jsonify


app = Flask(__name__)
client = MongoClient(port=27017)
db = client['flu-db']

# %% [markdown]
# Create an API Endpoint:
# Define an endpoint that when visited, will query the database and return the results in JSON format.

# %%
@app.route('/data', methods=['GET'])
def get_data():
    collection = db['combined_national']
    documents = list(collection.find({}, {'_id': 0}))  # Exclude the '_id' field
    return jsonify(documents)

# %% [markdown]
# Run the Flask App:
# run the Flask app, which will serve the API on the default port (5000).

# %%
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\richa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3468: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
